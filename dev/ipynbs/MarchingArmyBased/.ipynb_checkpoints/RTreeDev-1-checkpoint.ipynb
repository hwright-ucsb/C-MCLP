# %%
import shapely
import math
import pyproj
import sys
import fiona
sys.path.append('../../../alg')

import matplotlib.pyplot as plt, pandas as pd, geopandas as gpd, numpy as np, osmnx as ox
import distance_buffer as db, border_generators as bg, marching_army as ma

from matplotlib import pyplot
from functools import partial
from shapely import geometry
from shapely.ops import transform
from descartes import PolygonPatch
from matplotlib.patches import Arc
from shapely.geometry import Point, Polygon, MultiPolygon, LineString
# %matplotlib inline

# %%
from scipy.stats import truncnorm

# %%
reload(db)
# Out:
# <module 'distance_buffer' from '../../../alg/distance_buffer.pyc'>

# %%
reload(ma)
# Out:
# <module 'marching_army' from '../../../alg/marching_army.pyc'>

# %%
reload(bg)
# Out:
# <module 'border_generators' from '../../../alg/border_generators.pyc'>

# %% [markdown]
# # Get place and show it

# %%
proj = partial(pyproj.transform, pyproj.Proj(init='epsg:4326'),pyproj.Proj(init='epsg:3857'))

# %%
gdf, placegeom = bg.getplace('Walnut Creek, California, USA')
# plot the city
transgeom = transform(proj, placegeom)
west, south, east, north = transgeom.bounds
bounds = [west, south, east, north]
fig, ax = plt.subplots(figsize=(6,6))
for polygon in transgeom:
    patch = PolygonPatch(polygon, fc='#cccccc', ec='k', alpha=0.5, zorder=2)
    ax.add_patch(patch)
    
ax.set_xlim(west, east)
ax.set_ylim(south, north)
#ax.axis('off')
plt.show()

# %% [markdown]
# # Create spatial index

# %%
sindex = gdf.sindex

# %% [markdown]
# ### let's randomly generate pts w/ a normal distribution and test the rtree

# %%
# code in this block is from:
# https://stackoverflow.com/questions/36894191/how-to-get-a-normal-distribution-within-a-range-in-numpy

def get_truncated_normal(mean=0, sd=1, low=0, upp=10):
    return truncnorm(
        (low - mean) / sd, (upp - mean) / sd, loc=mean, scale=sd)

# %%
X_x = get_truncated_normal((-13582000.0), 1000, bounds[0], bounds[2])
X_y = get_truncated_normal((4568000.0),1000,bounds[1],bounds[3])

# %%
tempx = X_x.rvs(1000)
tempy = X_y.rvs(1000)

# %%
random_pts = gpd.GeoDataFrame(data={'x':tempx, 'y':tempy})

# %%
random_pts['geometry'] = random_pts.apply(lambda row: Point((row['x'], row['y'])), axis=1)

# %%
pts_sindex = random_pts.sindex

# %%
# %%time
possible_matches_index = list(pts_sindex.intersection(bounds))
possible_matches = random_pts.iloc[possible_matches_index]
precise_matches = possible_matches[possible_matches.intersects(transgeom)]
points_within_geometry = precise_matches
points_outside_geometry = random_pts[~random_pts.isin(points_within_geometry)]
# Out:
# CPU times: user 734 ms, sys: 4.88 ms, total: 738 ms
# Wall time: 739 ms

# %%
# plot the cut-up city
fig, ax = plt.subplots(figsize=(6,6))
for polygon in transgeom:
    patch = PolygonPatch(polygon, fc='#cccccc', ec='k', alpha=0.5, zorder=3)
    ax.add_patch(patch)

ax.scatter(x=points_outside_geometry['x'], y=points_outside_geometry['y'], s=1, c='r', linewidth=0, zorder=1)
ax.scatter(x=points_within_geometry['x'], y=points_within_geometry['y'], s=1, c='b', linewidth=0, zorder=2)
    
ax.set_xlim(west, east)
ax.set_ylim(south, north)
ax.axis('off')
#plt.savefig("rtree-test1.png",  dpi=192 * 10)
plt.show()

# %%
optdist = 100*math.sqrt(3)
bounds = [bounds[0]-100.0, bounds[1]-100.0, bounds[2]+100.0,bounds[3]+100.0]

# %%
tbounds = transgeom.bounds

# %%
bounds
# Out:
# [-13592226.456990628,
#  4557095.678592932,
#  -13578719.013366627,
#  4571947.8160177665]

# %%
#  find diag point of geom's bounding box
diagdist = db.eucdist(tbounds[0],tbounds[1],tbounds[2],tbounds[3])[0]

# %%
diagdist
# Out:
# 19793.26114924441

# %%
x_int = int(math.ceil((abs(bounds[0]-bounds[2]))/optdist))
y_int = int(math.ceil((abs(bounds[1]-bounds[3]))/optdist))

stopx = bounds[0]+(x_int*optdist)
stopy = bounds[2]+(y_int*optdist)

# %%
xs = np.linspace(west,stopx,x_int)
ys = np.linspace(south,stopy,y_int)

# %%
x_grid,y_grid = np.meshgrid(xs, ys)

# %%
print gridtzip.shape
# Out:
# (2, 85, 77)

# %%
gridgpd = gpd.GeoDataFrame(data={'x':gridtzip[0,:,:].flatten(), 'y':gridtzip[1,:,:].flatten()})

# %%
t = gridtzip[0,:,:].flatten()

# %%
print len(t)
print len(xs)*len(ys)
# Out:
# 6545
# 6708

# %%
gridgpd['geometry'] = gridgpd.apply(lambda row: Point((row['x'], row['y'])), axis=1)

# %%
grid_index = gridgpd.sindex

# %%
# %%time
possible_matches_index = list(grid_index.intersection(bounds))
possible_matches = gridgpd.iloc[possible_matches_index]
precise_matches = possible_matches[possible_matches.intersects(transgeom)]
points_within_geometry = precise_matches
points_outside_geometry = gridgpd[~gridgpd.isin(points_within_geometry)]
# Out:
# CPU times: user 4.69 s, sys: 21 ms, total: 4.71 s
# Wall time: 4.73 s

# %%
# plot the cut-up city
fig, ax = plt.subplots(figsize=(6,6))
for polygon in transgeom:
    patch = PolygonPatch(polygon, fc='#cccccc', ec='k', alpha=0.5, zorder=3)
    ax.add_patch(patch)

ax.scatter(x=points_outside_geometry['x'], y=points_outside_geometry['y'], s=1, c='r', linewidth=0, zorder=1)
ax.scatter(x=points_within_geometry['x'], y=points_within_geometry['y'], s=1, c='b', linewidth=0, zorder=2)
    
ax.set_xlim(west, east)
ax.set_ylim(south, north)
ax.axis('off')
plt.savefig("rtree-testgrid2.png",  dpi=192 * 10)
plt.show()

# %% [markdown]
# # New procedure:
# - get a line
# - get a starting point on the line (*OR:* get a starting point then get a direction vector?)
# - gen array of x's, y's, then zip them
# - gen a spatial index from pts
# - intersect poly sindex with cand pt sindex

# %%
def gen_grid_pts(bds, starpt, rot_dir):
    #min x, min y, max x, max y
    
    cur = starpt

# %% [markdown]
# # Let's generate random points based on real data from the 2010 census
# - We can obtain GIS projects/shapefiles containing the block groups upon which data is collected in the census. source: https://www.census.gov/geo/maps-data/data/tiger-line.html
# - We can obtain data on matching the geographies/BG's to their codes from http://proximityone.com/bg-zip.htm . I was unable to easily synthesize this data from the Census website itself. note that it is important to be sure you are using 2010 census BG's / codes because the American Community Survey (ACS) has their own, and an ACS is done every year
# - Another resource with a good interactive/searchable map is https://www.policymap.com/maps ; you can search place, block group, tract, etc.
#
# ### How we will do it
# 1. get the geometries of the BG's from census data
# 2. overlap the geometries from the area you are interested in (this case, Walnut Creek, CA) to find out what BG's are in the region exactly; make sure you use the geom. version BEFORE translation
# 3. generate n random points within each BG, and distribute the population P listed in that block from the data amongst the generated points
# 4. how to deal with semi-overlapping bg's -- decide later

# %%
county = fiona.open("../../../data/CA_WalnutCreek/CTY_ContaCostra/county_013.shp")

# %%
county.crs
# Out:
# {'init': u'epsg:4269'}

# %%
print county.schema
# Out:
# {'geometry': 'Polygon', 'properties': OrderedDict([(u'STATEFP10', 'str:2'), (u'COUNTYFP10', 'str:3'), (u'TRACTCE10', 'str:6'), (u'BLOCKCE', 'str:4'), (u'BLOCKID10', 'str:15'), (u'PARTFLG', 'str:1'), (u'HOUSING10', 'int:9'), (u'POP10', 'int:9')])}

# %%
county_iter = iter(county)

# %%
county_first = next(county_iter)
#county_sec = next(county_iter)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-294-ac24e0746ad1> in <module>()
# ----> 1 county_first = next(county_iter)
#       2 #county_sec = next(county_iter)
#
# fiona/ogrext.pyx in fiona.ogrext.Iterator.__next__()
#
# StopIteration:

# %%
try_geom = shapely.geometry.shape(county_first['geometry'])

# %%
type(county_iter)
# Out:
# fiona.ogrext.Iterator

# %%
print len(county_first)
print type(county_first)
# Out:
# 4
# <type 'dict'>

# %%
poly_list = []
for polydict in county:
    poly_list.append(shapely.geometry.shape(polydict['geometry']))

# %%
type(poly_list[0])
# Out:
# shapely.geometry.polygon.Polygon

# %%
ig1, ax1 = plt.subplots(figsize=(6,6))
#west, south, east, north = 
for polygon in poly_list:
    patch = PolygonPatch(polygon, fc='#cccccc', ec='k', alpha=0.5, zorder=3)
    ax1.add_patch(patch)
    
ax1.set_xlim(-122.4, -121.4)
ax1.set_ylim(37.6, 38.2)
plt.show()

# %%
proj2 = partial(pyproj.transform, pyproj.Proj(init='epsg:4269'),pyproj.Proj(init='epsg:3857'))

# %%
transpoly_list = []
for poly in poly_list:
    transpoly_list.append(transform(proj2, poly))

# %%
tbds = transpoly_list[0].bounds

# %%
ig2, ax2 = plt.subplots(figsize=(6,6))
transpatches = []
#west, south, east, north = 
for polygon in transpoly_list:
    patch = PolygonPatch(polygon, fc='#cccccc', ec='k', alpha=0.5, zorder=3)
    transpatches.append(patch)
    ax2.add_patch(patch)
    
ax2.set_xlim(-13666000, tbds[2]+100000)
ax2.set_ylim(4540000, 4590000)
plt.show()

# %%
-13666000+50000
# Out:
# -13616000

# %%
transgeom.bounds
# Out:
# (-13592126.456990628,
#  4557195.678592932,
#  -13578819.013366627,
#  4571847.8160177665)

# %%
ig3, ax3 = plt.subplots(figsize=(20,20))
for polygon in transpoly_list:
    patch = PolygonPatch(polygon, fc='#cccccc', ec='k', alpha=0.5, zorder=2)
    ax3.add_patch(patch)

for polygon in transgeom:
    patch = PolygonPatch(polygon, fc='#f2b9ed', ec='r', alpha=0.5, zorder=1)
    ax3.add_patch(patch)

        
ax3.set_xlim(west, east)
ax3.set_ylim(south, north)
plt.show()

# %%
bg_dataframes = []
x_bg = []
y_bg = []
for poly in transpoly_list:
    tempx_bg = []
    tempy_bg = []
    if type(poly) is Polygon:
        ring = poly.exterior.coords
    else:
        ring = poly[0].exterior.coords
    for i in range(0, len(ring)):
        tempx_bg.append(ring[i][0])
        tempy_bg.append(ring[i][1])
    x_bg.append(tempx_bg)
    y_bg.append(tempy_bg)
        
    
# TODO: fix this loop to handle diff types of polygons (multi, and exterior/interior)

# %%
bg_dataframes = []

for i in range(0, len(x_bg)):
    tempframe = gpd.GeoDataFrame(data={'x':x_bg[i], 'y':x_bg[i]})
    tempframe['geometry'] = tempframe.apply(lambda row: Point((row['x'], row['y'])), axis=1)
    bg_dataframes.append(tempframe)

# %%
len(bg_dataframes)
# Out:
# 18309

# %%
# spatial index intersection for these polys
bg_sindex = []
for frame in bg_dataframes:
    bg_sindex.append(frame.sindex)

# %%
len(bg_sindex)
# Out:
# 18309

# %%
338302
# Out:
# (-13613767.81202897, 4580235.725023876)

# %%
tpoly_list = []
for polydict in county:
    if polydict['properties']['TRACTCE10'] == '338302':
        tpoly_list.append(shapely.geometry.shape(polydict['geometry']))

# %%
temp = []
for poly in tpoly_list:
    temp.append(transform(proj2, poly))
tpoly_list = temp

# %%
ingeom = []
outgeom = []
cnt = 0
tbounds = transgeom.bounds
for index in bg_sindex:
    tdataframe = bg_dataframes[cnt]
    cnt+=1
    tpossible_matches_index = list(index.intersection(tbounds))
    tpossible_matches = tdataframe.iloc[tpossible_matches_index]
    tprecise_matches = tpossible_matches[tpossible_matches.intersects(transgeom)]
    ingeom.append(tprecise_matches)
    if len(tprecise_matches) > 0:
        print ingeom
    tpoints_within_geometry = tprecise_matches
    outgeom.append(tdataframe[~tdataframe.isin(tpoints_within_geometry)])

# %%
print len(ingeom)
print len(outgeom)
# Out:
# 18309
# 18309

# %%
maxlen = 0
theone = 0
for i in range(0, len(ingeom)):
    if len(ingeom[i]) > maxlen:
        maxlen = len(ingeom[i])
        theone = ingeom[i]
    #if len(outgeom[i])>maxlen:
    #    maxlen=len(outgeom[i])
    #    theone = outgeom[i]

# %%
multitpoly = MultiPolygon(tpoly_list)

# %%
# plot the cut-up city
fig4, ax4 = plt.subplots(figsize=(10,10))
for polygon in transgeom:
    patch = PolygonPatch(polygon, fc='#cccccc', ec='k', alpha=0.5, zorder=1)
    ax4.add_patch(patch)

for p in multitpoly:
    #tpoly = Polygon([[p.x, p.y] for p in tpoly_list['geometry']])
    patch = PolygonPatch(p, fc='#f2b9ed', ec='k', alpha=0.5, zorder=2)
    ax4.add_patch(patch)
        

#west,south,east,north=multitpoly.bounds
west,south,east,north=transgeom.bounds

ax4.set_xlim(west, east)
ax4.set_ylim(south, north)
ax4.axis('off')
#plt.savefig("rtree-testgrid2.png",  dpi=192 * 10)
plt.show()

# %%
print multitpoly.bounds
print transgeom.bounds
# Out:
# (-13585847.993182087, 4564050.475657365, -13579936.371623512, 4568247.63492332)
# (-13592126.456990628, 4557195.678592932, -13578819.013366627, 4571847.8160177665)

# %%
for i in range(0, len(ingeom)):
    if len(ingeom[i])>0:
        tpoly = Polygon([[p.x, p.y] for p in ingeom[i]['geometry']])

        patch = PolygonPatch(tpoly, fc='#cccccc', ec='k', alpha=0.5, zorder=3)
        ax4.add_patch(patch)
        
        #ax4.scatter(x=ingeom[i]['x'], y=ingeom[i]['y'], s=1, c='r', linewidth=0, zorder=1)
    if len(outgeom[i])>0:
        tpoly = Polygon([[p.x, p.y] for p in outgeom[i]['geometry']])

        patch = PolygonPatch(tpoly, fc='#cccccc', ec='k', alpha=0.5, zorder=2)
        ax4.add_patch(patch)
        #ax4.scatter(x=outgeom[i]['x'], y=outgeom[i]['y'], s=1, c='b', linewidth=0, zorder=2)

# %%
# read in FACES file 
countyfaces = fiona.open("../../../data/CA_WalnutCreek/CTY_faces/tl_2010_06013_faces.shp")

# %%
#countyfaces.schema

# %%
# read in CA places (to get the place code)
ca_places = fiona.open("../../../data/CA_WalnutCreek/CA_places/tl_2010_06_place10.shp")

# %%
ca_places.schema
# Out:
# {'geometry': 'Polygon',
#  'properties': OrderedDict([(u'STATEFP10', 'str:2'),
#               (u'PLACEFP10', 'str:5'),
#               (u'PLACENS10', 'str:8'),
#               (u'GEOID10', 'str:7'),
#               (u'NAME10', 'str:100'),
#               (u'NAMELSAD10', 'str:100'),
#               (u'LSAD10', 'str:2'),
#               (u'CLASSFP10', 'str:2'),
#               (u'PCICBSA10', 'str:1'),
#               (u'PCINECTA10', 'str:1'),
#               (u'MTFCC10', 'str:5'),
#               (u'FUNCSTAT10', 'str:1'),
#               (u'ALAND10', 'int:14'),
#               (u'AWATER10', 'int:14'),
#               (u'INTPTLAT10', 'str:11'),
#               (u'INTPTLON10', 'str:12')])}

# %%
type(ca_places)
# Out:
# fiona.collection.Collection

# %%
def find_place(placename, fcollection):
    match = []
    for i in range(0, len(fcollection)):
        if fcollection[i]['properties']['NAME10'] == placename:
            match = fcollection[i]
    
    return match

# %%
m = find_place("Walnut Creek", ca_places)

# %%
m
# Out:
# {'geometry': {'coordinates': [[(-122.006951, 37.907626),
#     (-122.006958, 37.907137999999996),
#     (-122.006962, 37.906895999999996),
#     (-122.00688199999999, 37.906787),
#     (-122.006883, 37.906704999999995),
#     (-122.006891, 37.906098),
#     (-122.00689299999999, 37.906054),
#     (-122.006896, 37.906015),
#     (-122.006894, 37.905932),
#     (-122.00688199999999, 37.905837999999996),
#     (-122.006869, 37.905767),
#     (-122.006846, 37.905685999999996),
#     (-122.006817, 37.905606999999996),
#     (-122.006757, 37.905485),
#     (-122.006577, 37.905274),
#     (-122.006188, 37.90482),
#     (-122.005692, 37.904269),
#     (-122.005499, 37.904046),
#     (-122.005287, 37.903799),
#     (-122.005237, 37.903741),
#     (-122.004854, 37.903310999999995),
#     (-122.004803, 37.903254),
#     (-122.004711, 37.903143),
#     (-122.004607, 37.903029),
#     (-122.00484, 37.903000999999996),
#     (-122.006234, 37.90325),
#     (-122.006805, 37.903352),
#     (-122.006844, 37.903223),
#     (-122.007158, 37.902145999999995),
#     (-122.007212, 37.901962),
#     (-122.00479899999999, 37.901522),
#     (-122.003812, 37.901339),
#     (-122.004203, 37.900876),
#     (-122.005434, 37.8994),
#     (-122.00352699999999, 37.899676),
#     (-122.003676, 37.898964),
#     (-122.003098, 37.899122999999996),
#     (-122.002171, 37.899378999999996),
#     (-122.001986, 37.899858),
#     (-122.00197, 37.89993),
#     (-122.001892, 37.899882),
#     (-122.001905, 37.899813),
#     (-122.002084, 37.899363),
#     (-122.002391, 37.898979),
#     (-122.002431, 37.898924),
#     (-122.002456, 37.898863999999996),
#     (-122.002464, 37.898821),
#     (-122.00255899999999, 37.898412),
#     (-122.00259299999999, 37.897991),
#     (-122.002594, 37.897919),
#     (-122.002588, 37.897883),
#     (-122.002561, 37.897814),
#     (-122.002532, 37.897769),
#     (-122.002281, 37.897388),
#     (-122.002245, 37.897331),
#     (-122.002233, 37.897301),
#     (-122.00222099999999, 37.897238),
#     (-122.00222600000001, 37.897174),
#     (-122.002247, 37.897113),
#     (-122.002385, 37.896799),
#     (-122.002409, 37.896744),
#     (-122.002229, 37.896795),
#     (-122.002164, 37.896654999999996),
#     (-122.002173, 37.896574),
#     (-122.002396, 37.896405),
#     (-122.002505, 37.896425),
#     (-122.002531, 37.896333),
#     (-122.002551, 37.896232999999995),
#     (-122.002558, 37.896132),
#     (-122.002551, 37.896021),
#     (-122.002533, 37.895907),
#     (-122.00253000000001, 37.895824),
#     (-122.002539, 37.895709),
#     (-122.002584, 37.89559),
#     (-122.002417, 37.895402),
#     (-122.002518, 37.895119),
#     (-122.002518, 37.894762),
#     (-122.002621, 37.894624),
#     (-122.003402, 37.894417),
#     (-122.002949, 37.893059),
#     (-122.002571, 37.891920999999996),
#     (-122.002432, 37.891504999999995),
#     (-122.002228, 37.890892),
#     (-122.001001, 37.887569),
#     (-122.000782, 37.886976),
#     (-122.000038, 37.88496),
#     (-121.999808, 37.884335),
#     (-122.003044, 37.883517999999995),
#     (-122.00715199999999, 37.882483),
#     (-122.011277, 37.881443),
#     (-122.014022, 37.880749),
#     (-122.01488499999999, 37.880531999999995),
#     (-122.012171, 37.875417),
#     (-122.011716, 37.874559999999995),
#     (-122.010486, 37.872243),
#     (-122.01028600000001, 37.871866),
#     (-122.01476199999999, 37.872626),
#     (-122.01691, 37.87299),
#     (-122.01803, 37.87318),
#     (-122.018743, 37.873301),
#     (-122.019676, 37.873459),
#     (-122.020034, 37.87352),
#     (-122.02004600000001, 37.872875),
#     (-122.020061, 37.872067),
#     (-122.020078, 37.871159999999996),
#     (-122.020092, 37.870363999999995),
#     (-122.020095, 37.870225),
#     (-122.020099, 37.869982),
#     (-122.020115, 37.8691),
#     (-122.020132, 37.868215),
#     (-122.020146, 37.867560999999995),
#     (-122.02015399999999, 37.867128),
#     (-122.02016, 37.866833),
#     (-122.020163, 37.866467),
#     (-122.020164, 37.866386),
#     (-122.02016499999999, 37.866307),
#     (-122.02187599999999, 37.866358999999996),
#     (-122.022334, 37.866372999999996),
#     (-122.022734, 37.866409999999995),
#     (-122.022772, 37.866324999999996),
#     (-122.02288300000001, 37.866409999999995),
#     (-122.023239, 37.866409),
#     (-122.02317099999999, 37.871952),
#     (-122.023324, 37.872033),
#     (-122.02472900000001, 37.872776),
#     (-122.024738, 37.872836),
#     (-122.024717, 37.872884),
#     (-122.024723, 37.872941999999995),
#     (-122.024743, 37.872968),
#     (-122.024794, 37.872994999999996),
#     (-122.024856, 37.872999),
#     (-122.024887, 37.87299),
#     (-122.025599, 37.873400000000004),
#     (-122.026051, 37.873402),
#     (-122.026066, 37.872302999999995),
#     (-122.026093, 37.870505),
#     (-122.026028, 37.869797999999996),
#     (-122.026025, 37.868961999999996),
#     (-122.02611999999999, 37.868567999999996),
#     (-122.026142, 37.866606),
#     (-122.026151, 37.866488),
#     (-122.026216, 37.866482),
#     (-122.026405, 37.866437999999995),
#     (-122.026392, 37.867160999999996),
#     (-122.026483, 37.86716),
#     (-122.026906, 37.867157),
#     (-122.026896, 37.866778),
#     (-122.026885, 37.866315),
#     (-122.026978, 37.866288999999995),
#     (-122.027041, 37.866273),
#     (-122.027259, 37.866212999999995),
#     (-122.027353, 37.866188),
#     (-122.02747099999999, 37.866155),
#     (-122.027661, 37.866104),
#     (-122.027824, 37.866056),
#     (-122.027942, 37.866022),
#     (-122.028041, 37.865992999999996),
#     (-122.028339, 37.865907),
#     (-122.02843899999999, 37.865879),
#     (-122.028605, 37.865835),
#     (-122.028903, 37.867712999999995),
#     (-122.02893399999999, 37.867898),
#     (-122.030461, 37.867882),
#     (-122.030896, 37.867929),
#     (-122.031304, 37.867874),
#     (-122.035453, 37.867838),
#     (-122.03544, 37.86756),
#     (-122.035382, 37.867169),
#     (-122.035562, 37.866772),
#     (-122.03601499999999, 37.866098),
#     (-122.036277, 37.86571),
#     (-122.037029, 37.865707),
#     (-122.037933, 37.86625),
#     (-122.038089, 37.867768999999996),
#     (-122.038541, 37.868384),
#     (-122.038752, 37.86867),
#     (-122.03879, 37.868722),
#     (-122.039821, 37.868688999999996),
#     (-122.040655, 37.869819),
#     (-122.04082199999999, 37.869721),
#     (-122.040995, 37.869602),
#     (-122.041055, 37.869571),
#     (-122.041237, 37.869478),
#     (-122.041298, 37.869448),
#     (-122.041411, 37.869353),
#     (-122.04145, 37.869319999999995),
#     (-122.041629, 37.869563),
#     (-122.04171, 37.869768),
#     (-122.041871, 37.870152),
#     (-122.042198, 37.870391999999995),
#     (-122.042273, 37.870447),
#     (-122.042473, 37.870762),
#     (-122.042704, 37.871126),
#     (-122.042765, 37.871221),
#     (-122.04298, 37.871454),
#     (-122.04399, 37.871744),
#     (-122.04428, 37.872138),
#     (-122.044378, 37.872271999999995),
#     (-122.044822, 37.872875),
#     (-122.044867, 37.872934),
#     (-122.044843, 37.872959),
#     (-122.044353, 37.873414),
#     (-122.044332, 37.873429),
#     (-122.044352, 37.873464),
#     (-122.04459299999999, 37.873884),
#     (-122.044673, 37.874024),
#     (-122.044735, 37.874145999999996),
#     (-122.045124, 37.873978),
#     (-122.045491, 37.874626),
#     (-122.045395, 37.874668),
#     (-122.045564, 37.874750999999996),
#     (-122.045714, 37.874867),
#     (-122.045758, 37.874901),
#     (-122.04590999999999, 37.875017),
#     (-122.046078, 37.875146),
#     (-122.046112, 37.875135),
#     (-122.046862, 37.875744999999995),
#     (-122.047527, 37.875529),
#     (-122.04792, 37.875419),
#     (-122.048266, 37.876025999999996),
#     (-122.048926, 37.877255),
#     (-122.049233, 37.877877),
#     (-122.049753, 37.878788),
#     (-122.049826, 37.87873),
#     (-122.049904, 37.878665999999996),
#     (-122.050011, 37.878839),
#     (-122.050031, 37.878865999999995),
#     (-122.050092, 37.878949999999996),
#     (-122.050173, 37.879112),
#     (-122.05022199999999, 37.879284999999996),
#     (-122.050274, 37.879424),
#     (-122.05052599999999, 37.880137999999995),
#     (-122.050729, 37.880598),
#     (-122.05080000000001, 37.880735),
#     (-122.050935, 37.880973999999995),
#     (-122.05112199999999, 37.88122),
#     (-122.05134799999999, 37.88147),
#     (-122.051609, 37.881751),
#     (-122.05185399999999, 37.881671),
#     (-122.052115, 37.881586),
#     (-122.052731, 37.881515),
#     (-122.052802, 37.881506),
#     (-122.053044, 37.881589999999996),
#     (-122.053291, 37.881676999999996),
#     (-122.05336299999999, 37.88165),
#     (-122.05434, 37.881288999999995),
#     (-122.054679, 37.880925),
#     (-122.05456, 37.880576),
#     (-122.054889, 37.880502),
#     (-122.055268, 37.880404),
#     (-122.055418, 37.880378),
#     (-122.055641, 37.880534999999995),
#     (-122.055795, 37.880603),
#     (-122.05584, 37.880721),
#     (-122.05602999999999, 37.881209999999996),
#     (-122.05607599999999, 37.881299),
#     (-122.056217, 37.881567),
#     (-122.056265, 37.881657),
#     (-122.05628899999999, 37.881653),
#     (-122.05636200000001, 37.881643),
#     (-122.056387, 37.88164),
#     (-122.056415, 37.881636),
#     (-122.0565, 37.881623999999995),
#     (-122.056529, 37.881620999999996),
#     (-122.056653, 37.881605),
#     (-122.05702600000001, 37.881557),
#     (-122.057151, 37.881541999999996),
#     (-122.057321, 37.881522),
#     (-122.057394, 37.881510999999996),
#     (-122.058123, 37.881402),
#     (-122.058366, 37.881366),
#     (-122.05856299999999, 37.881336),
#     (-122.05858, 37.881333),
#     (-122.058976, 37.881271),
#     (-122.059223, 37.881240999999996),
#     (-122.059439, 37.881215),
#     (-122.059641, 37.881189),
#     (-122.060249, 37.881112),
#     (-122.060452, 37.881087),
#     (-122.06055599999999, 37.88107),
#     (-122.06087099999999, 37.881018999999995),
#     (-122.060976, 37.881003),
#     (-122.061124, 37.880981999999996),
#     (-122.061297, 37.880958),
#     (-122.061571, 37.880924),
#     (-122.061721, 37.880907),
#     (-122.061781, 37.880897),
#     (-122.065131, 37.880353),
#     (-122.066456, 37.880139),
#     (-122.06661199999999, 37.876785),
#     (-122.06666799999999, 37.875597),
#     (-122.066733, 37.874188),
#     (-122.066711, 37.873989),
#     (-122.062674, 37.872589),
#     (-122.061597, 37.872298),
#     (-122.059078, 37.871635),
#     (-122.058953, 37.871587),
#     (-122.058797, 37.866968),
#     (-122.058779, 37.866434),
#     (-122.058808, 37.866285),
#     (-122.05883399999999, 37.865252999999996),
#     (-122.058808, 37.864900999999996),
#     (-122.057734, 37.864188999999996),
#     (-122.057565, 37.864176),
#     (-122.057006, 37.864191),
#     (-122.054422, 37.864291),
#     (-122.054177, 37.864292),
#     (-122.054078, 37.864263),
#     (-122.054032, 37.864215),
#     (-122.05396999999999, 37.864090999999995),
#     (-122.053917, 37.863878),
#     (-122.053796, 37.863774),
#     (-122.053471, 37.863583),
#     (-122.05334500000001, 37.863453),
#     (-122.05322, 37.863344999999995),
#     (-122.053088, 37.860732999999996),
#     (-122.053009, 37.859145),
#     (-122.052699, 37.852955),
#     (-122.052549, 37.849948),
#     (-122.052648, 37.849945999999996),
#     (-122.052542, 37.847242),
#     (-122.052357, 37.842497),
#     (-122.05273, 37.842507999999995),
#     (-122.06156899999999, 37.842983),
#     (-122.06165899999999, 37.845866),
#     (-122.06746, 37.84945),
#     (-122.068017, 37.849444999999996),
#     (-122.071181, 37.852022),
#     (-122.075296, 37.853576),
#     (-122.077114, 37.854921999999995),
#     (-122.078279, 37.855784),
#     (-122.07798700000001, 37.856750999999996),
#     (-122.079476, 37.860048),
#     (-122.081475, 37.865282),
#     (-122.081545, 37.865463999999996),
#     (-122.082685, 37.868096),
#     (-122.083394, 37.869029999999995),
#     (-122.08412799999999, 37.869907),
#     (-122.086344, 37.872552),
#     (-122.088986, 37.875237999999996),
#     (-122.089331, 37.875268999999996),
#     (-122.08933, 37.875361999999996),
#     (-122.089473, 37.875451999999996),
#     (-122.089699, 37.881108999999995),
#     (-122.08970099999999, 37.881319),
#     (-122.089274, 37.881423999999996),
#     (-122.08807, 37.881779),
#     (-122.087748, 37.881878),
#     (-122.087622, 37.881861),
#     (-122.08726300000001, 37.881678),
#     (-122.086826, 37.881665999999996),
#     (-122.086209, 37.881524),
#     (-122.086017, 37.881443999999995),
#     (-122.085639, 37.881585),
#     (-122.085455, 37.881648),
#     (-122.084701, 37.881689),
#     (-122.084486, 37.881595),
#     (-122.084191, 37.881397),
#     (-122.084029, 37.881294),
#     (-122.083155, 37.881212999999995),
#     (-122.082874, 37.881273),
#     (-122.081711, 37.881164),
#     (-122.08160000000001, 37.881181),
#     (-122.081217, 37.881276),
#     (-122.080969, 37.881150999999996),
#     (-122.080777, 37.881076),
#     (-122.08064, 37.881063),
#     (-122.08057600000001, 37.881057),
#     (-122.080575, 37.881056),
#     (-122.079274, 37.880624),
#     (-122.07896099999999, 37.880635),
#     (-122.078944, 37.880587),
#     (-122.076274, 37.880634),
#     (-122.076342, 37.880770999999996),
#     (-122.076445, 37.880975),
#     (-122.076509, 37.880977),
#     (-122.076729, 37.881482),
#     (-122.07658, 37.881482999999996),
#     (-122.07640599999999, 37.881485),
#     (-122.076424, 37.881513),
#     (-122.07649599999999, 37.881642),
#     (-122.07661999999999, 37.881859999999996),
#     (-122.076979, 37.882624),
#     (-122.077074, 37.882826),
#     (-122.077133, 37.882954999999995),
#     (-122.076757, 37.883033999999995),
#     (-122.076218, 37.883291),
#     (-122.075959, 37.882962),
#     (-122.076072, 37.882888),
#     (-122.07543, 37.882317),
#     (-122.07475, 37.881712),
#     (-122.074782, 37.881702),
#     (-122.074811, 37.881685),
#     (-122.074832, 37.881662),
#     (-122.07484099999999, 37.881629),
#     (-122.074833, 37.881595),
#     (-122.074818, 37.881575),
#     (-122.07479000000001, 37.881557),
#     (-122.07476299999999, 37.881547999999995),
#     (-122.074742, 37.881544999999996),
#     (-122.074727, 37.881546),
#     (-122.074725, 37.881475),
#     (-122.07418200000001, 37.881473),
#     (-122.072348, 37.881465999999996),
#     (-122.07074399999999, 37.881454999999995),
#     (-122.069942, 37.881448999999996),
#     (-122.068944, 37.881448999999996),
#     (-122.068101, 37.88145),
#     (-122.06800000000001, 37.881952999999996),
#     (-122.067799, 37.882447),
#     (-122.06739, 37.882611),
#     (-122.066494, 37.882956),
#     (-122.065851, 37.883258999999995),
#     (-122.065987, 37.883445),
#     (-122.066007, 37.883463),
#     (-122.06602699999999, 37.883471),
#     (-122.066067, 37.883477),
#     (-122.065941, 37.883534999999995),
#     (-122.065854, 37.883576999999995),
#     (-122.06584699999999, 37.883561),
#     (-122.065848, 37.883538),
#     (-122.065837, 37.883516),
#     (-122.065702, 37.883328),
#     (-122.064989, 37.883663),
#     (-122.065038, 37.883724),
#     (-122.06454, 37.884034),
#     (-122.063799, 37.884437999999996),
#     (-122.063437, 37.884625),
#     (-122.063223, 37.884695),
#     (-122.062943, 37.884774),
#     (-122.062772, 37.884822),
#     (-122.062613, 37.884853),
#     (-122.062386, 37.884896999999995),
#     (-122.062275, 37.884903),
#     (-122.062118, 37.88485),
#     (-122.062337, 37.885684),
#     (-122.06240700000001, 37.885886),
#     (-122.062521, 37.886328),
#     (-122.062613, 37.886136),
#     (-122.063234, 37.88615),
#     (-122.063216, 37.886401),
#     (-122.063297, 37.886724),
#     (-122.063296, 37.887521),
#     (-122.063319, 37.887761),
#     (-122.063346, 37.888011999999996),
#     (-122.063369, 37.888231),
#     (-122.063389, 37.888414),
#     (-122.06341, 37.888616),
#     (-122.06359, 37.888605),
#     (-122.063972, 37.888566),
#     (-122.064408, 37.889323999999995),
#     (-122.064672, 37.888943999999995),
#     (-122.06495100000001, 37.888512),
#     (-122.06504, 37.889489999999995),
#     (-122.06508099999999, 37.889626),
#     (-122.064911, 37.889834),
#     (-122.06485599999999, 37.889869999999995),
#     (-122.06468100000001, 37.889986),
#     (-122.064567, 37.890062),
#     (-122.064488, 37.89009),
#     (-122.064386, 37.890129),
#     (-122.063914, 37.890311),
#     (-122.063872, 37.890242),
#     (-122.063519, 37.890313),
#     (-122.06318999999999, 37.890378),
#     (-122.06308, 37.890034),
#     (-122.062876, 37.890057),
#     (-122.062736, 37.890063999999995),
#     (-122.062406, 37.89013),
#     (-122.062418, 37.889925),
#     (-122.062433, 37.889686),
#     (-122.062225, 37.889728),
#     (-122.062065, 37.889759999999995),
#     (-122.062066, 37.890021),
#     (-122.062117, 37.890136),
#     (-122.06205299999999, 37.89015),
#     (-122.062071, 37.890205),
#     (-122.061734, 37.890273),
#     (-122.06171499999999, 37.890249),
#     (-122.061249, 37.890344999999996),
#     (-122.06080399999999, 37.890523),
#     (-122.061381, 37.890782),
#     (-122.062794, 37.891417),
#     (-122.062894, 37.891282),
#     (-122.062986, 37.891324999999995),
#     (-122.06307, 37.891365),
#     (-122.063008, 37.89145),
#     (-122.063263, 37.891601),
#     (-122.063401, 37.891653999999996),
#     (-122.063898, 37.891846),
#     (-122.063961, 37.89187),
#     (-122.064431, 37.891947),
#     (-122.06472600000001, 37.892123999999995),
#     (-122.065566, 37.892447),
#     (-122.065639, 37.892468),
#     (-122.065775, 37.892674),
#     (-122.065935, 37.892736),
#     (-122.066124, 37.892787999999996),
#     (-122.06645499999999, 37.892887),
#     (-122.066977, 37.893135),
#     (-122.067195, 37.893178),
#     (-122.067352, 37.892987),
#     (-122.067613, 37.892793999999995),
#     (-122.06764799999999, 37.892723),
#     (-122.067695, 37.892633),
#     (-122.067737, 37.892553),
#     (-122.06786, 37.892329),
#     (-122.06800799999999, 37.892325),
#     (-122.068181, 37.892320999999995),
#     (-122.068274, 37.892305),
#     (-122.068157, 37.892579999999995),
#     (-122.068139, 37.892624999999995),
#     (-122.06859299999999, 37.892831),
#     (-122.068799, 37.893014),
#     (-122.068915, 37.893240999999996),
#     (-122.068927, 37.893297),
#     (-122.06893600000001, 37.893358),
#     (-122.06893600000001, 37.893443999999995),
#     (-122.06894299999999, 37.893581),
#     (-122.068944, 37.893719),
#     (-122.069413, 37.894068),
#     (-122.069463, 37.894352),
#     (-122.06959499999999, 37.894466),
#     (-122.070007, 37.89461),
#     (-122.070137, 37.894655),
#     (-122.07013, 37.894580999999995),
#     (-122.070128, 37.89451),
#     (-122.070122, 37.894299),
#     (-122.070121, 37.894228999999996),
#     (-122.070117, 37.89409),
#     (-122.070111, 37.893864),
#     (-122.070669, 37.893862),
#     (-122.070767, 37.893862),
#     (-122.070775, 37.893667),
#     (-122.07141, 37.89367),
#     (-122.071414, 37.893800999999996),
#     (-122.07352, 37.893823999999995),
#     (-122.073509, 37.894133),
#     (-122.073483, 37.894828),
#     (-122.073383, 37.894853),
#     (-122.07308499999999, 37.894931),
#     (-122.072986, 37.894957),
#     (-122.073628, 37.895050999999995),
#     (-122.075555, 37.895336),
#     (-122.076198, 37.895430999999995),
#     (-122.076523, 37.895503),
#     (-122.076536, 37.895506),
#     (-122.076953, 37.895561),
#     (-122.077507, 37.895677),
#     (-122.077655, 37.895708),
#     (-122.077822, 37.895783),
#     (-122.07782399999999, 37.895795),
#     (-122.077843, 37.895838999999995),
#     (-122.07789, 37.895899),
#     (-122.077955, 37.895945999999995),
#     (-122.078007, 37.89597),
#     (-122.078063, 37.895986),
#     (-122.078402, 37.896007999999995),
#     (-122.078495, 37.896018),
#     (-122.078623, 37.896032999999996),
#     (-122.078842, 37.896071),
#     (-122.079055, 37.896122999999996),
#     (-122.07926499999999, 37.896198999999996),
#     (-122.08066099999999, 37.896764),
#     (-122.080692, 37.896777),
#     (-122.080834, 37.89683),
#     (-122.080826, 37.897068999999995),
#     (-122.080826, 37.897087),
#     (-122.080826, 37.897099),
#     (-122.080816, 37.897385),
#     (-122.080813, 37.897472),
#     (-122.080811, 37.897565),
#     (-122.080996, 37.897607),
#     (-122.080994, 37.897653999999996),
#     (-122.080985, 37.898112999999995),
#     (-122.080803, 37.898112),
#     (-122.080801, 37.89823),
#     (-122.080801, 37.898333),
#     (-122.080103, 37.898333),
#     (-122.079724, 37.898333),
#     (-122.079472, 37.898292),
#     (-122.079167, 37.898255999999996),
#     (-122.078974, 37.898219),
#     (-122.07881, 37.898174),
#     (-122.07851600000001, 37.898106),
#     (-122.078233, 37.898052),
#     (-122.077968, 37.897991999999995),
#     (-122.077752, 37.897943),
#     (-122.07773, 37.897939),
#     (-122.077709, 37.897766),
#     (-122.07709, 37.897808999999995),
#     (-122.075928, 37.897815),
#     (-122.075875, 37.897815),
#     (-122.075724, 37.897706),
#     (-122.075529, 37.897597999999995),
#     (-122.075316, 37.897793),
#     (-122.075057, 37.898032),
#     (-122.07457600000001, 37.898503999999996),
#     (-122.07427799999999, 37.898292999999995),
#     (-122.074159, 37.898209),
#     (-122.07412099999999, 37.898250999999995),
#     (-122.074062, 37.898317),
#     (-122.073925, 37.898379),
#     (-122.073674, 37.898624999999996),
#     (-122.073605, 37.898778),
#     (-122.07363699999999, 37.898835),
#     (-122.073826, 37.899173999999995),
#     (-122.073827, 37.899298),
#     (-122.073829, 37.899463),
#     (-122.073545, 37.900065999999995),
#     (-122.073406, 37.900186999999995),
#     (-122.073573, 37.900207),
#     (-122.073885, 37.900546999999996),
#     (-122.074679, 37.899932),
#     (-122.074893, 37.899983),
#     (-122.074815, 37.900399),
#     (-122.075666, 37.900594),
#     (-122.074984, 37.901219999999995),
#     (-122.074953, 37.90126),
#     (-122.075965, 37.901340999999995),
#     (-122.075966, 37.901328),
#     (-122.076258, 37.900892999999996),
#     (-122.07636, 37.9009),
#     (-122.07659699999999, 37.900915),
#     (-122.076801, 37.900968),
#     (-122.077103, 37.901047999999996),
#     (-122.077691, 37.901213),
#     (-122.078211, 37.901357),
#     (-122.07995199999999, 37.902274999999996),
#     (-122.081521, 37.903098),
#     (-122.081611, 37.9031),
#     (-122.08162, 37.90315),
#     (-122.081694, 37.903189),
#     (-122.083992, 37.903149),
#     (-122.084042, 37.903876),
#     (-122.084074, 37.904432),
#     (-122.083978, 37.904471),
#     (-122.083233, 37.904669),
#     (-122.08229299999999, 37.904474),
#     (-122.082263, 37.904554999999995),
#     (-122.08221499999999, 37.904689999999995),
#     (-122.082177, 37.904799),
#     (-122.082148, 37.904880999999996),
#     (-122.081952, 37.904753),
#     (-122.081775, 37.904717999999995),
#     (-122.08121, 37.904682),
#     (-122.080854, 37.904672),
#     (-122.08066099999999, 37.904685),
#     (-122.080663, 37.904609),
#     (-122.08068, 37.903597),
#     (-122.080687, 37.903206),
#     (-122.07991799999999, 37.903214999999996),
#     (-122.078899, 37.903228),
#     (-122.078613, 37.903231),
#     (-122.07674, 37.903251999999995),
#     (-122.076221, 37.903258),
#     (-122.0762, 37.903096),
#     (-122.075986, 37.9031),
#     (-122.075838, 37.903104),
#     (-122.075865, 37.903317),
#     (-122.075702, 37.90332),
#     (-122.075634, 37.903321),
#     (-122.07548, 37.903321999999996),
#     (-122.075017, 37.903327),
#     (-122.07486399999999, 37.903329),
#     (-122.074495, 37.903341999999995),
#     (-122.07338899999999, 37.903380999999996),
#     (-122.073021, 37.903394999999996),
#     (-122.073062, 37.903439999999996),
#     (-122.073068, 37.903447),
#     (-122.073165, 37.903593),
#     (-122.073199, 37.903645),
#     (-122.073278, 37.90376),
#     (-122.073308, 37.903808),
#     (-122.073311, 37.903853),
#     (-122.073328, 37.903948),
#     (-122.073327, 37.904044),
#     (-122.073305, 37.904179),
#     (-122.07327699999999, 37.90428),
#     (-122.073219, 37.904429),
#     (-122.073154, 37.904548),
#     (-122.07287, 37.904365),
#     (-122.072518, 37.904137),
#     (-122.07243199999999, 37.904174999999995),
#     (-122.071449, 37.904187),
#     (-122.071666, 37.904537999999995),
#     (-122.073218, 37.907041),
#     (-122.072572, 37.907126999999996),
#     (-122.072182, 37.907178),
#     (-122.072021, 37.907219999999995),
#     (-122.071974, 37.907258),
#     (-122.071724, 37.907374),
#     (-122.071696, 37.90739),
#     (-122.071582, 37.907461),
#     (-122.07146399999999, 37.907568999999995),
#     (-122.07123899999999, 37.90786),
#     (-122.071049, 37.90804),
#     (-122.070903, 37.908147),
#     (-122.070887, 37.908159999999995),
#     (-122.07077100000001, 37.908232999999996),
#     (-122.070668, 37.908328999999995),
#     (-122.07058, 37.908319),
#     (-122.070514, 37.908377),
#     (-122.070351, 37.908468),
#     (-122.07032, 37.908485999999996),
#     (-122.070176, 37.908587),
#     (-122.07004599999999, 37.908699),
#     (-122.069931, 37.90882),
#     (-122.06983199999999, 37.908950999999995),
#     (-122.06980300000001, 37.908995999999995),
#     (-122.069778, 37.909046),
#     (-122.069746, 37.909115),
#     (-122.06967399999999, 37.90923),
#     (-122.069636, 37.909281),
#     (-122.069678, 37.909329),
#     (-122.06973099999999, 37.909389),
#     (-122.069801, 37.909478),
#     (-122.069842, 37.909529),
#     (-122.06985, 37.909538999999995),
#     (-122.069874, 37.909569999999995),
#     (-122.069883, 37.909580999999996),
#     (-122.07000099999999, 37.909746999999996),
#     (-122.070525, 37.909544),
#     (-122.070617, 37.909687),
#     (-122.071188, 37.909459),
#     (-122.07141899999999, 37.909816),
#     (-122.07199800000001, 37.90958),
#     (-122.072204, 37.909497),
#     (-122.07222, 37.909521999999996),
#     (-122.072476, 37.909417999999995),
#     (-122.072461, 37.909393),
#     (-122.073052, 37.909164),
#     (-122.073125, 37.909136),
#     (-122.073262, 37.909261),
#     (-122.07335499999999, 37.909347),
#     (-122.073414, 37.909400999999995),
#     (-122.07373799999999, 37.909698999999996),
#     (-122.074319, 37.909437),
#     (-122.07453, 37.909341),
#     (-122.074726, 37.909253),
#     (-122.07538199999999, 37.910205999999995),
#     (-122.076257, 37.911547999999996),
#     (-122.076818, 37.911364),
#     (-122.079764, 37.910402999999995),
#     (-122.08250699999999, 37.910484),
#     (-122.082965, 37.910464999999995),
#     (-122.084549, 37.910522),
#     (-122.08541199999999, 37.910553),
#     (-122.08657, 37.910595),
#     (-122.088953, 37.910233999999996),
#     (-122.090343, 37.910024),
#     (-122.090874, 37.910024),
#     (-122.091409, 37.910036999999996),
#     (-122.091611, 37.910043),
#     (-122.091839, 37.910049),
#     (-122.092068, 37.910055),
#     (-122.093111, 37.910061999999996),
#     (-122.094588, 37.910074),
#     (-122.095882, 37.910129),
#     (-122.096242, 37.910143),
#     (-122.097268, 37.910182999999996),
#     (-122.097263, 37.910166),
#     (-122.0976, 37.910174),
#     (-122.097621, 37.910174),
#     (-122.097937, 37.910182),
#     (-122.098496, 37.910195),
#     (-122.098696, 37.910199),
#     (-122.09905499999999, 37.910208),
#     (-122.099034, 37.910252),
#     (-122.098969, 37.910444999999996),
#     (-122.098952, 37.910509999999995),
#     (-122.098589, 37.911643999999995),
#     (-122.098488, 37.911961),
#     (-122.098484, 37.911972999999996),
#     (-122.09844, 37.912165),
#     (-122.098415, 37.912372),
#     (-122.098413, 37.912579),
#     (-122.098433, 37.912786),
#     (-122.098476, 37.91299),
#     (-122.098478, 37.912999),
#     (-122.098516, 37.913125),
#     (-122.098597, 37.913323999999996),
#     (-122.098627, 37.913387),
#     (-122.098735, 37.913575),
#     (-122.09881899999999, 37.913697),
#     (-122.09896, 37.913871),
#     (-122.09896499999999, 37.913875999999995),
#     (-122.099065, 37.913982),
#     (-122.099228, 37.914175),
#     (-122.09932599999999, 37.914308999999996),
#     (-122.099457, 37.914517),
#     (-122.099533, 37.91466),
#     (-122.09962999999999, 37.914879),
#     (-122.099705, 37.915102999999995),
#     (-122.099743, 37.915254999999995),
#     (-122.099808, 37.915645),
#     (-122.09984, 37.915836),
#     (-122.099912, 37.916304),
#     (-122.09993, 37.916461999999996),
#     (-122.099972, 37.916817),
#     (-122.099981, 37.91694),
#     (-122.099993, 37.917100000000005),
#     (-122.100009, 37.917308),
#     (-122.100011, 37.917398),
#     (-122.099091, 37.917403),
#     (-122.097914, 37.91739),
#     (-122.097305, 37.917384),
#     (-122.096708, 37.917375),
#     (-122.095461, 37.917308),
#     (-122.094251, 37.917294),
#     (-122.092417, 37.917300000000004),
#     (-122.09177199999999, 37.917303),
#     (-122.091998, 37.917691),
#     (-122.092103, 37.918154),
#     (-122.092289, 37.918572),
#     (-122.09227, 37.918928),
#     (-122.092247, 37.919056),
#     (-122.092506, 37.920162999999995),
#     (-122.092546, 37.920331999999995),
#     (-122.093846, 37.919720999999996),
#     (-122.09447399999999, 37.919425),
#     (-122.094706, 37.919331),
#     (-122.094762, 37.919404),
#     (-122.09482299999999, 37.919486),
#     (-122.094855, 37.919528),
#     (-122.094951, 37.919657),
#     (-122.094984, 37.9197),
#     (-122.095083, 37.919832),
#     (-122.095291, 37.92004),
#     (-122.095326, 37.920069),
#     (-122.095603, 37.920297),
#     (-122.096155, 37.920345999999995),
#     (-122.096481, 37.920578),
#     (-122.096498, 37.92075),
#     (-122.096479, 37.920775),
#     (-122.096371, 37.92093),
#     (-122.096302, 37.921081),
#     (-122.09634199999999, 37.921226),
#     (-122.09628000000001, 37.921306),
#     (-122.096279, 37.921307999999996),
#     (-122.096108, 37.921557),
#     (-122.096051, 37.921641),
#     (-122.09601599999999, 37.921693),
#     (-122.095918, 37.921704999999996),
#     (-122.094807, 37.921844),
#     (-122.094005, 37.922256999999995),
#     (-122.093774, 37.922381),
#     (-122.093669, 37.922409),
#     (-122.093255, 37.922492),
#     (-122.092942, 37.921701999999996),
#     (-122.09289, 37.921571),
#     (-122.092885, 37.921563),
#     (-122.092746, 37.921315),
#     (-122.092622, 37.92135),
#     (-122.092472, 37.920826999999996),
#     (-122.092328, 37.920826999999996),
#     (-122.091815, 37.920975),
#     (-122.091308, 37.921098),
#     (-122.091183, 37.921127),
#     (-122.091086, 37.920863),
#     (-122.091041, 37.920739),
#     (-122.090874, 37.920801999999995),
#     (-122.090766, 37.920848),
#     (-122.09063, 37.920908),
#     (-122.090397, 37.921028),
#     (-122.08997, 37.921234999999996),
#     (-122.089705, 37.921365),
#     (-122.08967799999999, 37.921378),
#     (-122.08959, 37.92141),
#     (-122.08957, 37.921414),
#     (-122.089522, 37.921425),
#     (-122.089479, 37.924813),
#     (-122.089469, 37.924943999999996),
#     (-122.089428, 37.924954),
#     (-122.08931, 37.924983),
#     (-122.088603, 37.925137),
#     (-122.088444, 37.925169),
#     (-122.088116, 37.925236),
#     (-122.087997, 37.92526),
#     (-122.087893, 37.925281999999996),
#     (-122.087755, 37.925315999999995),
#     (-122.087732, 37.925323),
#     (-122.087552, 37.92538),
#     (-122.087422, 37.925430999999996),
#     (-122.08723499999999, 37.925519),
#     (-122.08668, 37.925847999999995),
#     (-122.086465, 37.925976999999996),
#     (-122.086334, 37.926034),
#     (-122.0862, 37.92608),
#     (-122.086141, 37.926094),
#     (-122.08603099999999, 37.926122),
#     (-122.085857, 37.926148),
#     (-122.085739, 37.926156),
#     (-122.085541, 37.926159999999996),
#     (-122.08534, 37.926165999999995),
#     (-122.08516399999999, 37.926169),
#     (-122.084948, 37.926173999999996),
#     (-122.084636, 37.926181),
#     (-122.084557, 37.926183),
#     (-122.084461, 37.926185),
#     (-122.084324, 37.926187),
#     (-122.083917, 37.926193999999995),
#     (-122.083781, 37.926196999999995),
#     (-122.083665, 37.926198),
#     (-122.08332, 37.926204),
#     (-122.08320499999999, 37.926206),
#     (-122.082968, 37.926207999999995),
#     (-122.082736, 37.926210999999995),
#     (-122.082735, 37.926210999999995),
#     (-122.08225999999999, 37.926227),
#     (-122.082025, 37.926235999999996),
#     (-122.08197799999999, 37.926235999999996),
#     (-122.081838, 37.92624),
#     (-122.08179200000001, 37.926241999999995),
#     (-122.081638, 37.926246),
#     (-122.081399, 37.926252999999996),
#     (-122.081176, 37.926255999999995),
#     (-122.081023, 37.926259),
#     (-122.080869, 37.92626),
#     (-122.080409, 37.926266),
#     (-122.08025599999999, 37.926269),
#     (-122.080214, 37.926269),
#     (-122.08009, 37.926269999999995),
#     (-122.080049, 37.926271),
#     (-122.079869, 37.926269999999995),
#     (-122.079329, 37.926269),
#     (-122.079149, 37.926269),
#     (-122.079127, 37.926269),
#     (-122.07906299999999, 37.926269),
#     (-122.079042, 37.926269),
#     (-122.078888, 37.926266999999996),
#     (-122.078722, 37.926266),
#     (-122.07842600000001, 37.926275),
#     (-122.078273, 37.926280999999996),
#     (-122.078113, 37.926286),
#     (-122.07801, 37.926289),
#     (-122.077953, 37.926291),
#     (-122.077837, 37.926294999999996),
#     (-122.077223, 37.92631),
#     (-122.076961, 37.926317),
#     (-122.076756, 37.92632),
#     (-122.07672600000001, 37.926321),
#     (-122.076492, 37.926325),
#     (-122.076216, 37.926328999999996),
#     (-122.076144, 37.92633),
#     (-122.07594, 37.926333),
#     (-122.075763, 37.926334),
#     (-122.075232, 37.926338),
#     (-122.075056, 37.926339999999996),
#     (-122.074984, 37.926339999999996),
#     (-122.074772, 37.926339999999996),
#     (-122.074701, 37.926341),
#     (-122.074596, 37.926341),
#     (-122.074284, 37.926341),
#     (-122.07418, 37.926341),
#     (-122.074045, 37.926339999999996),
#     (-122.073642, 37.926337),
#     (-122.073508, 37.926336),
#     (-122.073509, 37.92655),
#     (-122.07351, 37.926742),
#     (-122.073512, 37.927147),
#     (-122.073512, 37.927192),
#     (-122.073512, 37.927277),
#     (-122.07351299999999, 37.927406999999995),
#     (-122.07351299999999, 37.927562),
#     (-122.073516, 37.928027),
#     (-122.073517, 37.928182),
#     (-122.073517, 37.928284),
#     (-122.073517, 37.928284999999995),
#     (-122.073517, 37.928595),
#     (-122.073518, 37.928699),
#     (-122.073519, 37.928889999999996),
#     (-122.073522, 37.929463),
#     (-122.073523, 37.929655),
#     (-122.073523, 37.929775),
#     (-122.073525, 37.930135),
#     (-122.073526, 37.930254999999995),
#     (-122.073525, 37.930333),
#     (-122.073525, 37.930391),
#     (-122.073525, 37.930800999999995),
#     (-122.073525, 37.930938),
#     (-122.073523, 37.931636999999995),
#     (-122.073516, 37.932297),
#     (-122.073514, 37.932468),
#     (-122.073507, 37.933006),
#     (-122.07350199999999, 37.933246),
#     (-122.073499, 37.933399),
#     (-122.070234, 37.933389999999996),
#     (-122.067655, 37.933102),
#     (-122.067531, 37.933267),
#     (-122.066965, 37.933107),
#     (-122.066862, 37.933071999999996),
#     (-122.06679199999999, 37.933037999999996),
#     (-122.066665, 37.933246),
#     (-122.06624, 37.933032),
#     (-122.06604899999999, 37.933064),
#     (-122.06533, 37.932773),
#     (-122.064388, 37.932748),
#     (-122.064385, 37.932831),
#     (-122.06363999999999, 37.932826999999996),
#     ...],
#    [(-122.042926, 37.897726999999996),
#     (-122.04302, 37.897711),
#     (-122.042881, 37.897907),
#     (-122.042801, 37.898227),
#     (-122.042951, 37.898181),
#     (-122.042971, 37.898176),
#     (-122.04323099999999, 37.898104),
#     (-122.043289, 37.898106999999996),
#     (-122.043311, 37.898114),
#     (-122.04370399999999, 37.898041),
#     (-122.04488599999999, 37.897825999999995),
#     (-122.04527999999999, 37.897755),
#     (-122.045564, 37.897704999999995),
#     (-122.046419, 37.897558),
#     (-122.046704, 37.89751),
#     (-122.046925, 37.897431),
#     (-122.046897, 37.89738),
#     (-122.047337, 37.896964),
#     (-122.047077, 37.896758),
#     (-122.047054, 37.896739),
#     (-122.04762, 37.896164999999996),
#     (-122.047591, 37.896132),
#     (-122.047544, 37.896055),
#     (-122.047503, 37.895959999999995),
#     (-122.04739000000001, 37.895657),
#     (-122.04737399999999, 37.895612),
#     (-122.04731699999999, 37.895469999999996),
#     (-122.047242, 37.895323),
#     (-122.047135, 37.895159),
#     (-122.047067, 37.895078999999996),
#     (-122.046985, 37.895007),
#     (-122.046913, 37.894959),
#     (-122.046891, 37.894945),
#     (-122.046786, 37.894889),
#     (-122.046769, 37.89488),
#     (-122.046606, 37.894785999999996),
#     (-122.046456, 37.894694),
#     (-122.0464, 37.894641),
#     (-122.04636099999999, 37.894579),
#     (-122.046339, 37.894512),
#     (-122.046333, 37.89442),
#     (-122.046333, 37.894417),
#     (-122.046337, 37.894393),
#     (-122.045823, 37.894397),
#     (-122.045714, 37.894421),
#     (-122.045091, 37.894563999999995),
#     (-122.044977, 37.894255),
#     (-122.044731, 37.89401),
#     (-122.04360199999999, 37.894284),
#     (-122.04361399999999, 37.894206),
#     (-122.04364699999999, 37.894087999999996),
#     (-122.043678, 37.894011),
#     (-122.04372599999999, 37.893811),
#     (-122.043733, 37.893782),
#     (-122.04303999999999, 37.89364),
#     (-122.042876, 37.894225),
#     (-122.042864, 37.894331),
#     (-122.043267, 37.894374),
#     (-122.043127, 37.895005),
#     (-122.043126, 37.895112),
#     (-122.043021, 37.895035),
#     (-122.04297700000001, 37.895002999999996),
#     (-122.042743, 37.89485),
#     (-122.042683, 37.894815),
#     (-122.04259, 37.894760999999995),
#     (-122.042579, 37.894754999999996),
#     (-122.042325, 37.894624),
#     (-122.042306, 37.894611999999995),
#     (-122.042216, 37.894555),
#     (-122.041927, 37.894667999999996),
#     (-122.041061, 37.895009),
#     (-122.040773, 37.895123999999996),
#     (-122.04068, 37.895089999999996),
#     (-122.040171, 37.895237),
#     (-122.039869, 37.895446),
#     (-122.039822, 37.895508),
#     (-122.039631, 37.895759999999996),
#     (-122.039712, 37.895824),
#     (-122.039848, 37.895919),
#     (-122.040035, 37.896035999999995),
#     (-122.040185, 37.89613),
#     (-122.04054099999999, 37.896378),
#     (-122.040694, 37.89651),
#     (-122.04081, 37.896625),
#     (-122.040877, 37.896708),
#     (-122.040959, 37.89684),
#     (-122.041039, 37.896912),
#     (-122.041125, 37.897),
#     (-122.04114799999999, 37.897024),
#     (-122.041287, 37.897200000000005),
#     (-122.041345, 37.897247),
#     (-122.041414, 37.897283),
#     (-122.041492, 37.897304999999996),
#     (-122.041397, 37.897492),
#     (-122.041386, 37.897515999999996),
#     (-122.041434, 37.897653999999996),
#     (-122.041618, 37.898120999999996),
#     (-122.04176, 37.89848),
#     (-122.042068, 37.898388),
#     (-122.042411, 37.897923),
#     (-122.042498, 37.897801),
#     (-122.042926, 37.897726999999996)],
#    [(-122.046205, 37.90555),
#     (-122.04504299999999, 37.906127999999995),
#     (-122.045005, 37.906148),
#     (-122.044299, 37.906562),
#     (-122.044004, 37.906332),
#     (-122.043982, 37.906248),
#     (-122.043973, 37.906223),
#     (-122.04384, 37.905867),
#     (-122.043787, 37.90571),
#     (-122.043705, 37.905474),
#     (-122.043473, 37.905349),
#     (-122.043381, 37.905302999999996),
#     (-122.043292, 37.905269),
#     (-122.043199, 37.905243),
#     (-122.043148, 37.905232999999996),
#     (-122.04308499999999, 37.905221999999995),
#     (-122.043016, 37.905214),
#     (-122.042899, 37.905209),
#     (-122.042795, 37.905212999999996),
#     (-122.042709, 37.905204999999995),
#     (-122.042602, 37.905181),
#     (-122.042494, 37.905136),
#     (-122.04231300000001, 37.905071),
#     (-122.041527, 37.904621),
#     (-122.041496, 37.904618),
#     (-122.041104, 37.90459),
#     (-122.041016, 37.904618),
#     (-122.040986, 37.904632),
#     (-122.040909, 37.904677),
#     (-122.040868, 37.90471),
#     (-122.040808, 37.904773),
#     (-122.040616, 37.905004),
#     (-122.039607, 37.905516),
#     (-122.039159, 37.905397),
#     (-122.03888, 37.905322999999996),
#     (-122.03884099999999, 37.905311999999995),
#     (-122.038724, 37.905280999999995),
#     (-122.038686, 37.905271),
#     (-122.038587, 37.905094999999996),
#     (-122.038448, 37.905015999999996),
#     (-122.03778, 37.903942),
#     (-122.037469, 37.903594999999996),
#     (-122.037383, 37.903538),
#     (-122.037122, 37.903400000000005),
#     (-122.03701, 37.903357),
#     (-122.036793, 37.903265),
#     (-122.036741, 37.903197),
#     (-122.03673599999999, 37.903144),
#     (-122.036744, 37.903115),
#     (-122.03677, 37.903075),
#     (-122.03682599999999, 37.903036),
#     (-122.03698, 37.903003999999996),
#     (-122.037149, 37.902981),
#     (-122.037421, 37.902938999999996),
#     (-122.037915, 37.902867),
#     (-122.03811999999999, 37.902833),
#     (-122.03822, 37.9028),
#     (-122.03831, 37.902752),
#     (-122.038358, 37.902713999999996),
#     (-122.038415, 37.902654),
#     (-122.038462, 37.902577),
#     (-122.03849, 37.902463999999995),
#     (-122.038483, 37.902364999999996),
#     (-122.038452, 37.902283),
#     (-122.03840000000001, 37.902207),
#     (-122.038341, 37.902150999999996),
#     (-122.038246, 37.902124),
#     (-122.03831199999999, 37.902051),
#     (-122.03903199999999, 37.901266),
#     (-122.038726, 37.901084),
#     (-122.038847, 37.900956),
#     (-122.038716, 37.90096),
#     (-122.03864, 37.900833999999996),
#     (-122.038507, 37.900825),
#     (-122.038478, 37.9007),
#     (-122.038369, 37.900755),
#     (-122.037705, 37.900742),
#     (-122.037605, 37.900375),
#     (-122.037301, 37.900518999999996),
#     (-122.037306, 37.900391),
#     (-122.036921, 37.900273),
#     (-122.036774, 37.900216),
#     (-122.036755, 37.900338999999995),
#     (-122.036519, 37.900093),
#     (-122.036137, 37.900236),
#     (-122.035537, 37.899747),
#     (-122.03565499999999, 37.899642),
#     (-122.035267, 37.899571),
#     (-122.035154, 37.899457999999996),
#     (-122.035308, 37.899265),
#     (-122.034825, 37.899324),
#     (-122.034377, 37.898892),
#     (-122.034328, 37.898821999999996),
#     (-122.034117, 37.898565),
#     (-122.033855, 37.898765),
#     (-122.033803, 37.898835999999996),
#     (-122.03362899999999, 37.899042),
#     (-122.033324, 37.899035),
#     (-122.033092, 37.899031),
#     (-122.033248, 37.899907999999996),
#     (-122.033306, 37.900887),
#     (-122.033314, 37.901314),
#     (-122.033351, 37.902011),
#     (-122.033373, 37.902415999999995),
#     (-122.033373, 37.903141999999995),
#     (-122.033373, 37.903424),
#     (-122.033424, 37.903444),
#     (-122.033451, 37.904084),
#     (-122.033459, 37.904258999999996),
#     (-122.033124, 37.904171),
#     (-122.032314, 37.90396),
#     (-122.02944, 37.903211),
#     (-122.026636, 37.902482),
#     (-122.026431, 37.904219),
#     (-122.026358, 37.904832999999996),
#     (-122.026115, 37.906901999999995),
#     (-122.026073, 37.90726),
#     (-122.02606399999999, 37.907388),
#     (-122.026039, 37.907775),
#     (-122.026031, 37.907903999999995),
#     (-122.026022, 37.907941),
#     (-122.025998, 37.908054),
#     (-122.02599000000001, 37.908091999999996),
#     (-122.02596199999999, 37.90826),
#     (-122.025961, 37.908265),
#     (-122.025937, 37.908792999999996),
#     (-122.02592899999999, 37.90897),
#     (-122.02592899999999, 37.909022),
#     (-122.02592899999999, 37.909181),
#     (-122.02592899999999, 37.909234),
#     (-122.02593, 37.909417999999995),
#     (-122.025933, 37.909662),
#     (-122.025931, 37.909971999999996),
#     (-122.02593, 37.910157),
#     (-122.025928, 37.910277),
#     (-122.025925, 37.910637),
#     (-122.025924, 37.910758),
#     (-122.025923, 37.910813999999995),
#     (-122.025923, 37.910982),
#     (-122.025923, 37.911038999999995),
#     (-122.026122, 37.910987),
#     (-122.026146, 37.910982),
#     (-122.026434, 37.910925999999996),
#     (-122.026587, 37.910888),
#     (-122.02664899999999, 37.910838),
#     (-122.026785, 37.910754),
#     (-122.026955, 37.910652),
#     (-122.026986, 37.910644),
#     (-122.02708200000001, 37.910618),
#     (-122.027372, 37.910543),
#     (-122.027469, 37.910519),
#     (-122.027457, 37.91041),
#     (-122.027422, 37.910083),
#     (-122.027411, 37.909974),
#     (-122.027372, 37.909622999999996),
#     (-122.027345, 37.909075),
#     (-122.02738099999999, 37.909009999999995),
#     (-122.027536, 37.908736),
#     (-122.028726, 37.909279),
#     (-122.029281, 37.909532),
#     (-122.029411, 37.909591999999996),
#     (-122.029652, 37.909723),
#     (-122.030376, 37.910119),
#     (-122.030618, 37.910250999999995),
#     (-122.030844, 37.91032),
#     (-122.032592, 37.9112),
#     (-122.033569, 37.910295999999995),
#     (-122.03449, 37.910796),
#     (-122.036318, 37.908994),
#     (-122.03662, 37.909202),
#     (-122.036765, 37.909302),
#     (-122.03684799999999, 37.909357),
#     (-122.036869, 37.909371),
#     (-122.037094, 37.90953),
#     (-122.037177, 37.909588),
#     (-122.037264, 37.909649),
#     (-122.03742199999999, 37.909748),
#     (-122.03746699999999, 37.909779),
#     (-122.037651, 37.909904),
#     (-122.03770399999999, 37.909943999999996),
#     (-122.03889699999999, 37.908111999999996),
#     (-122.038619, 37.907936),
#     (-122.038509, 37.907872999999995),
#     (-122.038182, 37.907686),
#     (-122.038073, 37.907624),
#     (-122.037537, 37.907263),
#     (-122.03873899999999, 37.905543),
#     (-122.040224, 37.905977),
#     (-122.041111, 37.906236),
#     (-122.043149, 37.906757999999996),
#     (-122.047328, 37.907816),
#     (-122.05024399999999, 37.908572),
#     (-122.050338, 37.908682999999996),
#     (-122.050482, 37.908634),
#     (-122.050536, 37.90869),
#     (-122.050601, 37.908715),
#     (-122.050674, 37.908716999999996),
#     (-122.050756, 37.908685999999996),
#     (-122.050813, 37.908612999999995),
#     (-122.05080699999999, 37.908533999999996),
#     (-122.05134799999999, 37.908367999999996),
#     (-122.051262, 37.908315),
#     (-122.051172, 37.908269),
#     (-122.051152, 37.908259),
#     (-122.051037, 37.908209),
#     (-122.050878, 37.908114999999995),
#     (-122.050569, 37.907916),
#     (-122.05037, 37.907769),
#     (-122.050182, 37.907612),
#     (-122.05008, 37.907502),
#     (-122.049787, 37.907187),
#     (-122.04975400000001, 37.907151999999996),
#     (-122.049643, 37.907033999999996),
#     (-122.049578, 37.906967),
#     (-122.04941, 37.906815),
#     (-122.049349, 37.906748),
#     (-122.049271, 37.906639),
#     (-122.049212, 37.906524),
#     (-122.04898, 37.906600000000005),
#     (-122.048753, 37.906684999999996),
#     (-122.048685, 37.906715999999996),
#     (-122.04861199999999, 37.906739),
#     (-122.048496, 37.906760999999996),
#     (-122.048378, 37.906763999999995),
#     (-122.04831, 37.906752999999995),
#     (-122.048246, 37.906732999999996),
#     (-122.048158, 37.90669),
#     (-122.048085, 37.906631),
#     (-122.047917, 37.906535),
#     (-122.047765, 37.906424),
#     (-122.047672, 37.906343),
#     (-122.047214, 37.906026),
#     (-122.047074, 37.905908),
#     (-122.046973, 37.905836),
#     (-122.04681099999999, 37.905738),
#     (-122.046671, 37.905673),
#     (-122.046573, 37.905636),
#     (-122.046387, 37.90558),
#     (-122.04631499999999, 37.905563),
#     (-122.046205, 37.90555)],
#    [(-122.039752, 37.890377),
#     (-122.039715, 37.890359),
#     (-122.039301, 37.890158),
#     (-122.038772, 37.889902),
#     (-122.037889, 37.889472999999995),
#     (-122.037368, 37.88922),
#     (-122.03699499999999, 37.889043),
#     (-122.036915, 37.889005),
#     (-122.036884, 37.888974999999995),
#     (-122.036685, 37.888881),
#     (-122.035725, 37.888427),
#     (-122.035724, 37.888427),
#     (-122.03523, 37.888194999999996),
#     (-122.03526600000001, 37.888148),
#     (-122.03548, 37.887865),
#     (-122.035588, 37.887723),
#     (-122.03567100000001, 37.887613),
#     (-122.036111, 37.887828),
#     (-122.036254, 37.88764),
#     (-122.036458, 37.887375999999996),
#     (-122.036527, 37.8873),
#     (-122.036595, 37.887226999999996),
#     (-122.037056, 37.886624),
#     (-122.037137, 37.886517999999995),
#     (-122.037433, 37.88666),
#     (-122.037508, 37.886696),
#     (-122.03788, 37.886874),
#     (-122.03817699999999, 37.887017),
#     (-122.038324, 37.887087),
#     (-122.03802, 37.887468999999996),
#     (-122.037711, 37.887884),
#     (-122.037819, 37.887937),
#     (-122.037973, 37.888005),
#     (-122.03816, 37.888087999999996),
#     (-122.038431, 37.888217999999995),
#     (-122.038494, 37.888248999999995),
#     (-122.038584, 37.88829),
#     (-122.038782, 37.888380999999995),
#     (-122.039234, 37.888588),
#     (-122.039373, 37.888663),
#     (-122.039565, 37.888768),
#     (-122.039683, 37.888829),
#     (-122.039743, 37.888855),
#     (-122.039963, 37.888951),
#     (-122.04015799999999, 37.889044999999996),
#     (-122.040235, 37.889097),
#     (-122.040269, 37.88913),
#     (-122.040299, 37.889159),
#     (-122.040333, 37.889206),
#     (-122.040358, 37.889255999999996),
#     (-122.040366, 37.8893),
#     (-122.040467, 37.889288),
#     (-122.040569, 37.889283999999996),
#     (-122.040571, 37.889283999999996),
#     (-122.040673, 37.889305),
#     (-122.040772, 37.889339),
#     (-122.040862, 37.889385),
#     (-122.040942, 37.889441999999995),
#     (-122.04113100000001, 37.889531999999996),
#     (-122.04131699999999, 37.889621),
#     (-122.04162, 37.889719),
#     (-122.04172299999999, 37.889752),
#     (-122.041917, 37.889812),
#     (-122.04144, 37.890173),
#     (-122.041493, 37.890091999999996),
#     (-122.041031, 37.890384),
#     (-122.041186, 37.890552),
#     (-122.04136, 37.89074),
#     (-122.041404, 37.890786),
#     (-122.041459, 37.890797),
#     (-122.041568, 37.890817999999996),
#     (-122.041843, 37.890868999999995),
#     (-122.041831, 37.891152),
#     (-122.041814, 37.891568),
#     (-122.04182, 37.891596),
#     (-122.041862, 37.891636999999996),
#     (-122.041902, 37.891709999999996),
#     (-122.041946, 37.891746999999995),
#     (-122.04225, 37.891999),
#     (-122.04231, 37.891919),
#     (-122.042379, 37.891843),
#     (-122.042498, 37.89174),
#     (-122.042599, 37.891662),
#     (-122.042671, 37.891583),
#     (-122.04272499999999, 37.891495),
#     (-122.04275, 37.891433),
#     (-122.042825, 37.891135999999996),
#     (-122.043954, 37.891335),
#     (-122.043862, 37.891625),
#     (-122.04499200000001, 37.891774),
#     (-122.04505, 37.891738),
#     (-122.045095, 37.891723),
#     (-122.045143, 37.891715999999995),
#     (-122.04539, 37.891718999999995),
#     (-122.045612, 37.891731),
#     (-122.04593, 37.891757999999996),
#     (-122.04626999999999, 37.891777999999995),
#     (-122.046273, 37.891723999999996),
#     (-122.04639, 37.891069),
#     (-122.046427, 37.890957),
#     (-122.04656299999999, 37.891006999999995),
#     (-122.046678, 37.89104),
#     (-122.04685599999999, 37.891075),
#     (-122.046977, 37.891089),
#     (-122.04832, 37.891203999999995),
#     (-122.049093, 37.891276),
#     (-122.049194, 37.891293),
#     (-122.04928699999999, 37.891318),
#     (-122.049362, 37.891208),
#     (-122.049811, 37.890735),
#     (-122.050621, 37.889885),
#     (-122.051927, 37.888515),
#     (-122.051137, 37.888045999999996),
#     (-122.050633, 37.887755999999996),
#     (-122.050488, 37.887671),
#     (-122.050363, 37.887614),
#     (-122.050063, 37.88748),
#     (-122.049874, 37.887329),
#     (-122.05109, 37.886897),
#     (-122.051168, 37.886821),
#     (-122.05076, 37.886334),
#     (-122.05027799999999, 37.885759),
#     (-122.049916, 37.88534),
#     (-122.049766, 37.885166999999996),
#     (-122.049598, 37.884966),
#     (-122.049512, 37.88487),
#     (-122.049394, 37.884710999999996),
#     (-122.04925399999999, 37.884476),
#     (-122.049145, 37.884231),
#     (-122.04907, 37.883979),
#     (-122.04902799999999, 37.883722),
#     (-122.048997, 37.88337),
#     (-122.049004, 37.883303999999995),
#     (-122.048748, 37.883151),
#     (-122.048554, 37.882863),
#     (-122.04778999999999, 37.883179),
#     (-122.047665, 37.883218),
#     (-122.046624, 37.883547),
#     (-122.046564, 37.883559999999996),
#     (-122.046554, 37.88346),
#     (-122.046502, 37.882973),
#     (-122.046479, 37.882746999999995),
#     (-122.04648399999999, 37.882719),
#     (-122.046486, 37.882673),
#     (-122.046483, 37.882625),
#     (-122.046477, 37.882574),
#     (-122.046472, 37.882525),
#     (-122.046466, 37.882475),
#     (-122.046459, 37.882424),
#     (-122.046452, 37.882373),
#     (-122.046445, 37.882323),
#     (-122.046443, 37.882276),
#     (-122.046436, 37.882225999999996),
#     (-122.04643, 37.882177999999996),
#     (-122.046427, 37.882131),
#     (-122.046426, 37.882083),
#     (-122.046423, 37.882034999999995),
#     (-122.046419, 37.881989),
#     (-122.046386, 37.881797999999996),
#     (-122.046256, 37.881792),
#     (-122.045927, 37.881777),
#     (-122.045905, 37.881696),
#     (-122.045924, 37.881394),
#     (-122.045931, 37.881282999999996),
#     (-122.045951, 37.880949),
#     (-122.045961, 37.880863),
#     (-122.045871, 37.880865),
#     (-122.045802, 37.880866),
#     (-122.045446, 37.880855),
#     (-122.045202, 37.880849),
#     (-122.044777, 37.880826),
#     (-122.044336, 37.880787999999995),
#     (-122.044174, 37.880770999999996),
#     (-122.043752, 37.880727),
#     (-122.04346100000001, 37.880697999999995),
#     (-122.043024, 37.880669999999995),
#     (-122.042615, 37.880649),
#     (-122.042206, 37.880646),
#     (-122.042014, 37.880654),
#     (-122.041725, 37.880655),
#     (-122.041437, 37.880644),
#     (-122.041347, 37.880631),
#     (-122.041079, 37.880579999999995),
#     (-122.040817, 37.880514999999995),
#     (-122.040082, 37.880286),
#     (-122.03990999999999, 37.880224999999996),
#     (-122.03970000000001, 37.880159),
#     (-122.039407, 37.880085),
#     (-122.039236, 37.880055),
#     (-122.039062, 37.88004),
#     (-122.038803, 37.880035),
#     (-122.03860399999999, 37.880013999999996),
#     (-122.038473, 37.87999),
#     (-122.038449, 37.879988999999995),
#     (-122.038412, 37.879987),
#     (-122.038303, 37.879968999999996),
#     (-122.03828, 37.879962),
#     (-122.038239, 37.879948999999996),
#     (-122.03815, 37.879906999999996),
#     (-122.038018, 37.879816),
#     (-122.037872, 37.879695),
#     (-122.03784, 37.879670999999995),
#     (-122.037769, 37.879629),
#     (-122.03769299999999, 37.879594),
#     (-122.037571, 37.879554),
#     (-122.037401, 37.879538),
#     (-122.037066, 37.879529999999995),
#     (-122.036878, 37.879526999999996),
#     (-122.036523, 37.879525),
#     (-122.035489, 37.879523),
#     (-122.035461, 37.879522),
#     (-122.035108, 37.879518),
#     (-122.034834, 37.879512),
#     (-122.034373, 37.879501999999995),
#     (-122.034013, 37.879504),
#     (-122.03374, 37.879506),
#     (-122.033722, 37.879506),
#     (-122.033671, 37.879506),
#     (-122.033654, 37.879507),
#     (-122.033422, 37.879506),
#     (-122.032727, 37.879503),
#     (-122.032496, 37.879501999999995),
#     (-122.032326, 37.879498),
#     (-122.032149, 37.879494),
#     (-122.03182, 37.879473999999995),
#     (-122.031802, 37.879473),
#     (-122.031651, 37.879470999999995),
#     (-122.031627, 37.879581),
#     (-122.031556, 37.879915),
#     (-122.031533, 37.880026),
#     (-122.031516, 37.881266),
#     (-122.031513, 37.881568),
#     (-122.031246, 37.881665),
#     (-122.030664, 37.881876),
#     (-122.029686, 37.882233),
#     (-122.027254, 37.883119),
#     (-122.02640199999999, 37.883429),
#     (-122.025995, 37.883578),
#     (-122.02583899999999, 37.883632999999996),
#     (-122.025037, 37.883924),
#     (-122.022233, 37.88494),
#     (-122.021991, 37.884938999999996),
#     (-122.021943, 37.885037),
#     (-122.01930899999999, 37.886002),
#     (-122.019529, 37.886091),
#     (-122.01956799999999, 37.886167),
#     (-122.019894, 37.886218),
#     (-122.020099, 37.886174),
#     (-122.020279, 37.886275),
#     (-122.020534, 37.886275999999995),
#     (-122.020572, 37.88615),
#     (-122.022778, 37.885888),
#     (-122.022927, 37.885889),
#     (-122.023794, 37.886564),
#     (-122.024519, 37.888245999999995),
#     (-122.024217, 37.889148),
#     (-122.024858, 37.889489),
#     (-122.025217, 37.88968),
#     (-122.025328, 37.88973),
#     (-122.025362, 37.889745999999995),
#     (-122.025587, 37.889841),
#     (-122.025304, 37.890254999999996),
#     (-122.02503, 37.890657),
#     (-122.024868, 37.890884),
#     (-122.02655, 37.891894),
#     (-122.026736, 37.891912),
#     (-122.026896, 37.89203),
#     (-122.02761699999999, 37.891985999999996),
#     (-122.028826, 37.8921),
#     (-122.029271, 37.892271),
#     (-122.029772, 37.892524),
#     (-122.029872, 37.892624),
#     (-122.030172, 37.892922999999996),
#     (-122.030272, 37.893024),
#     (-122.03089, 37.893086),
#     (-122.031389, 37.893324),
#     (-122.031573, 37.893324),
#     (-122.031814, 37.893495),
#     (-122.032539, 37.89401),
#     (-122.032721, 37.89414),
#     (-122.032781, 37.894182),
#     (-122.03363, 37.894757999999996),
#     (-122.034995, 37.895371),
#     (-122.035303, 37.895143999999995),
#     (-122.035651, 37.894784),
#     (-122.035802, 37.894602),
#     (-122.036097, 37.894252),
#     (-122.036262, 37.893788),
#     (-122.036325, 37.893693999999996),
#     (-122.036562, 37.893358),
#     (-122.036585, 37.893370999999995),
#     (-122.03661, 37.893293),
#     (-122.036993, 37.893117),
#     (-122.037081, 37.893077999999996),
#     (-122.037301, 37.892983),
#     (-122.037415, 37.892934),
#     (-122.037563, 37.892869),
#     (-122.037589, 37.892858),
#     (-122.037802, 37.892815999999996),
#     (-122.037853, 37.892807),
#     (-122.037992, 37.892779999999995),
#     (-122.038045, 37.892854),
#     (-122.038395, 37.892717),
#     (-122.038565, 37.892448),
#     (-122.038793, 37.89217),
#     (-122.038776, 37.892154999999995),
#     (-122.038822, 37.892112999999995),
#     (-122.038826, 37.892109999999995),
#     (-122.038936, 37.891999),
#     (-122.038956, 37.891982999999996),
#     (-122.039006, 37.891945),
#     (-122.039163, 37.891822999999995),
#     (-122.039286, 37.891729),
#     (-122.039433, 37.891644),
#     (-122.039448, 37.891635),
#     (-122.039509, 37.891684),
#     (-122.039678, 37.891917),
#     (-122.039817, 37.892033999999995),
#     (-122.039866, 37.892071),
#     (-122.039998, 37.892171),
#     (-122.040587, 37.891815),
#     (-122.040001, 37.891399),
#     (-122.039931, 37.891348),
#     (-122.039892, 37.89132),
#     (-122.039643, 37.891143),
#     (-122.039541, 37.891071),
#     (-122.039352, 37.89094),
#     (-122.039632, 37.890626),
#     (-122.039836, 37.890432),
#     (-122.039752, 37.890377)]],
#   'type': 'Polygon'},
#  'id': '307',
#  'properties': OrderedDict([(u'STATEFP10', u'06'),
#               (u'PLACEFP10', u'83346'),
#               (u'PLACENS10', u'02412174'),
#               (u'GEOID10', u'0683346'),
#               (u'NAME10', u'Walnut Creek'),
#               (u'NAMELSAD10', u'Walnut Creek city'),
#               (u'LSAD10', u'25'),
#               (u'CLASSFP10', u'C1'),
#               (u'PCICBSA10', u'Y'),
#               (u'PCINECTA10', u'N'),
#               (u'MTFCC10', u'G4110'),
#               (u'FUNCSTAT10', u'A'),
#               (u'ALAND10', 51169325),
#               (u'AWATER10', 31275),
#               (u'INTPTLAT10', u'+37.9026660'),
#               (u'INTPTLON10', u'-122.0404791')]),
#  'type': 'Feature'}

# %%
wc_census10 = shapely.geometry.shape(m['geometry'])

# %%
wc_census10 = transform(proj2, wc_census10)

# %%
wc_census10

# %%
transgeom.bounds
# Out:
# (-13592126.456990628,
#  4557195.678592932,
#  -13578819.013366627,
#  4571847.8160177665)

# %%
wc_census10.bounds
# Out:
# (-13592111.050373102, 4557199.7523299, -13578818.94657493, 4571791.477797462)

# %%
m['properties']
# Out:
# OrderedDict([(u'STATEFP10', u'06'),
#              (u'PLACEFP10', u'83346'),
#              (u'PLACENS10', u'02412174'),
#              (u'GEOID10', u'0683346'),
#              (u'NAME10', u'Walnut Creek'),
#              (u'NAMELSAD10', u'Walnut Creek city'),
#              (u'LSAD10', u'25'),
#              (u'CLASSFP10', u'C1'),
#              (u'PCICBSA10', u'Y'),
#              (u'PCINECTA10', u'N'),
#              (u'MTFCC10', u'G4110'),
#              (u'FUNCSTAT10', u'A'),
#              (u'ALAND10', 51169325),
#              (u'AWATER10', 31275),
#              (u'INTPTLAT10', u'+37.9026660'),
#              (u'INTPTLON10', u'-122.0404791')])

# %%
def match_place_to_faces(placefp10, faces_collec):
    matches = []
    for i in range(0, len(countyfaces)):
        if countyfaces[i]['properties']['PLACEFP10'] == placefp10:
            matches.append(countyfaces[i])
    
    return matches

# %%
wc_matches = match_place_to_faces(m['properties']['PLACEFP10'], countyfaces)

# %%
len(wc_matches)
# Out:
# 1614

# %%
wc_blockgeoms = []
for i in range(0, len(wc_matches)):
    wc_blockgeoms.append(shapely.geometry.shape(wc_matches[i]['geometry']))

# %%
len(wc_blockgeoms)
# Out:
# 1614

# %%
multi_wc_blockgeoms = MultiPolygon(wc_blockgeoms)

# %%
multi_wc_census10 = MultiPolygon([wc_census10])

# %%
tmulti_wc_blockgeoms = []
for poly in multi_wc_blockgeoms:
    tmulti_wc_blockgeoms.append(transform(proj2, poly))

# %%
len(tmulti_wc_blockgeoms)
# Out:
# 1614

# %%
fig5, ax5 = plt.subplots(figsize=(10,10))
for polygon in multi_wc_census10:
    patch = PolygonPatch(polygon, fc='#cccccc', ec='k', alpha=0.5, zorder=1)
    ax5.add_patch(patch)

for p in tmulti_wc_blockgeoms:
    #tpoly = Polygon([[p.x, p.y] for p in tpoly_list['geometry']])
    patch = PolygonPatch(p, fc='#f2b9ed', ec='k', alpha=0.5, zorder=2)
    ax5.add_patch(patch)
        

#west,south,east,north=multitpoly.bounds
west,south,east,north=wc_census10.bounds

ax5.set_xlim(west, east)
ax5.set_ylim(south, north)
ax5.axis('off')
#plt.savefig("rtree-testgrid2.png",  dpi=192 * 10)
plt.show()

# %%
wc_matches[0]
# Out:
# {'geometry': {'coordinates': [[(-122.075941, 37.917211),
#     (-122.075897, 37.917211),
#     (-122.075767, 37.917212),
#     (-122.075724, 37.917213),
#     (-122.075723, 37.917058),
#     (-122.075723, 37.916593),
#     (-122.075723, 37.916439),
#     (-122.075902, 37.916436),
#     (-122.076442, 37.91643),
#     (-122.076622, 37.916429),
#     (-122.076708, 37.916427),
#     (-122.07696899999999, 37.916423),
#     (-122.077056, 37.916423),
#     (-122.077094, 37.916478999999995),
#     (-122.07721, 37.916649),
#     (-122.077249, 37.916706),
#     (-122.077378, 37.916803),
#     (-122.07776799999999, 37.917096),
#     (-122.077826, 37.917139999999996),
#     (-122.077898, 37.917195),
#     (-122.077776, 37.917196),
#     (-122.077682, 37.917196),
#     (-122.077034, 37.917201999999996),
#     (-122.076819, 37.917204),
#     (-122.076643, 37.917204999999996),
#     (-122.076116, 37.917209),
#     (-122.075941, 37.917211)]],
#   'type': 'Polygon'},
#  'id': '57',
#  'properties': OrderedDict([(u'TFID', 203617776),
#               (u'STATEFP00', u'06'),
#               (u'COUNTYFP00', u'013'),
#               (u'TRACTCE00', u'340002'),
#               (u'BLKGRPCE00', u'3'),
#               (u'BLOCKCE00', u'3000'),
#               (u'COUSUBFP00', u'90440'),
#               (u'SUBMCDFP00', u''),
#               (u'CONCTYFP00', u''),
#               (u'PLACEFP00', u'83346'),
#               (u'AIANNHFP00', u''),
#               (u'AIANNHCE00', u''),
#               (u'COMPTYP00', u''),
#               (u'TRSUBFP00', u''),
#               (u'TRSUBCE00', u''),
#               (u'ANRCFP00', u''),
#               (u'ELSDLEA00', u'41250'),
#               (u'SCSDLEA00', u'01650'),
#               (u'UNSDLEA00', u''),
#               (u'UACE', u'19504'),
#               (u'CD108FP', u'10'),
#               (u'SLDUST00', u''),
#               (u'SLDLST00', u''),
#               (u'VTDST00', u''),
#               (u'ZCTA5CE00', u'94596'),
#               (u'TAZCE00', u'508382'),
#               (u'UGACE00', u''),
#               (u'PUMA5CE00', u'02104'),
#               (u'STATEFP10', u'06'),
#               (u'COUNTYFP10', u'013'),
#               (u'TRACTCE10', u'340002'),
#               (u'BLKGRPCE10', u'3'),
#               (u'BLOCKCE10', u'3002'),
#               (u'COUSUBFP10', u'90440'),
#               (u'SUBMCDFP10', u''),
#               (u'CONCTYFP10', u''),
#               (u'PLACEFP10', u'83346'),
#               (u'AIANNHFP10', u''),
#               (u'AIANNHCE10', u''),
#               (u'COMPTYP10', u''),
#               (u'TRSUBFP10', u''),
#               (u'TRSUBCE10', u''),
#               (u'ANRCFP10', u''),
#               (u'TTRACTCE10', u''),
#               (u'TBLKGPCE10', u''),
#               (u'ELSDLEA10', u'41250'),
#               (u'SCSDLEA10', u'01650'),
#               (u'UNSDLEA10', u''),
#               (u'UACE10', u'19504'),
#               (u'CD111FP', u'10'),
#               (u'SLDUST10', u'007'),
#               (u'SLDLST10', u'015'),
#               (u'VTDST10', u'21665'),
#               (u'ZCTA5CE10', u'94597'),
#               (u'TAZCE10', u''),
#               (u'UGACE10', u''),
#               (u'PUMACE10', u'01304'),
#               (u'CSAFP10', u'488'),
#               (u'CBSAFP10', u'41860'),
#               (u'METDIVFP10', u'36084'),
#               (u'CNECTAFP10', u''),
#               (u'NECTAFP10', u''),
#               (u'NCTADVFP10', u''),
#               (u'LWFLAG', u'L'),
#               (u'OFFSET', u'N'),
#               (u'ATOTAL', 12866),
#               (u'INTPTLAT', u'+37.9168504'),
#               (u'INTPTLON', u'-122.0765915')]),
#  'type': 'Feature'}

# %% [markdown]
# ## Now we'll read in the population info shapefile
#
# BLOCKID10 format:
#
# **Gsscccttttttbxxx**
#
# - ss = state FIPS code (STATEFP10)
#
# - ccc = county FIPS code (COUNTYFP10)
# - tttttt = census tract code (TRACTCE10)
# - b = census block group number (BLKGRPCE10)
# - bxxx = census block tabulation number (BLOCKCE10)
#
# Note: block assignment text files (BlockAssign_ST06_CA_INCPLACE_CDP.txt)
#
# but, it only found 987 blocks in walnut creek....

# %%
ca_pop_bg = fiona.open("../../../data/CA_WalnutCreek/CA_pop_bg/tabblock2010_06_pophu.shp")

# %%
ca_pop_bg.schema
# Out:
# {'geometry': 'Polygon',
#  'properties': OrderedDict([(u'STATEFP10', 'str:2'),
#               (u'COUNTYFP10', 'str:3'),
#               (u'TRACTCE10', 'str:6'),
#               (u'BLOCKCE', 'str:4'),
#               (u'BLOCKID10', 'str:15'),
#               (u'PARTFLG', 'str:1'),
#               (u'HOUSING10', 'int:9'),
#               (u'POP10', 'int:9')])}

# %%
print cc_pop_bg[0]['properties']['BLOCKID10']
print [wc_matches[0]['properties']['STATEFP10'], wc_matches[0]['properties']['COUNTYFP10'], wc_matches[0]['properties']['TRACTCE10'], wc_matches[0]['properties']['BLKGRPCE10'], wc_matches[0]['properties']['BLOCKCE10']]
print str(wc_matches[0]['properties']['STATEFP10'])+ str(wc_matches[0]['properties']['COUNTYFP10'])+str(wc_matches[0]['properties']['TRACTCE10'])+str(wc_matches[0]['properties']['BLOCKCE10'])
# Out:
# 060133591031014
# [u'06', u'013', u'340002', u'3', u'3002']
# 060133400023002

# %%
#filter to contra costa county
cc_pop_bg = []
for i in range(0, len(ca_pop_bg)):
    if ca_pop_bg[i]['properties']['COUNTYFP10'] == '013':
        cc_pop_bg.append(ca_pop_bg[i])

# %%
len(cc_pop_bg)
# Out:
# 18309

# %%
len(ca_pop_bg)
# Out:
# 710145

# %%
wc_pop_bg = []
for i in range(0,len(wc_matches)):
    matchstr = str(wc_matches[i]['properties']['STATEFP10'])+ str(wc_matches[i]['properties']['COUNTYFP10'])+str(wc_matches[i]['properties']['TRACTCE10'])+str(wc_matches[i]['properties']['BLOCKCE10'])
    for j in range(0, len(cc_pop_bg)):
        if cc_pop_bg[j]['properties']['BLOCKID10'] == matchstr:
            wc_pop_bg.append(cc_pop_bg[j])

# %%
print len(wc_pop_bg)
print len(wc_matches)
# Out:
# 1614
# 1614

# %%
temp_wc_pop_bg = []
dups = []
listofids = []
for i in range(0, len(wc_pop_bg)):
    tid = str(wc_pop_bg[i]['properties']['BLOCKID10'])
    if tid not in listofids:
        listofids.append(tid)
        temp_wc_pop_bg.append(wc_pop_bg[i])
    else:
        dups.append(wc_pop_bg[i])

# %%
# loop to make sure duplicates removed didnt have a differnet population
for i in range(0, len(dups)):
    thedup = str(dups[i]['properties']['BLOCKID10'])
    for j in range(0, len(temp_wc_pop_bg)):
        if thedup == str(temp_wc_pop_bg[j]['properties']['BLOCKID10']):
            p1 = dups[i]['properties']['POP10']
            p2 = temp_wc_pop_bg[j]['properties']['POP10']
            if not p1==p2:
                print p1
                print p2

# %%
print len(temp_wc_pop_bg)
wc_pop_bg = temp_wc_pop_bg
# Out:
# 987

# %%
#print transform(proj2, shapely.geometry.shape(wc_pop_bg[0]['geometry']))

# %%
#print multi_twc_pop_bg[0]

# %%
#print twc_pop_bg[0]

# %%
twc_pop_bg = []
for l in wc_pop_bg:
    twc_pop_bg.append(transform(proj2, shapely.geometry.shape(l['geometry'])))

# %%
print len(twc_pop_bg)
print type(twc_pop_bg[0])
# Out:
# 987
# <class 'shapely.geometry.polygon.Polygon'>

# %%
multi_twc_pop_bg = MultiPolygon(twc_pop_bg)

# %%
fig6, ax6 = plt.subplots(figsize=(10,10))
for polygon in multi_wc_census10:
    patch = PolygonPatch(polygon, fc='#cccccc', ec='k', alpha=0.5, zorder=1)
    ax6.add_patch(patch)

for i in range(0, len(multi_twc_pop_bg)):#p in multi_twc_pop_bg:
    #tpoly = Polygon([[p.x, p.y] for p in tpoly_list['geometry']])
    tpop = wc_pop_bg[i]['properties']['POP10']
    if tpop ==0: 
        tpop = 1
    patch = PolygonPatch(multi_twc_pop_bg[i], fc='#000000', ec='k', alpha=(tpop/(tpop+300.0)), zorder=2)
    ax6.add_patch(patch)
        

#west,south,east,north=multitpoly.bounds
west,south,east,north=multi_wc_census10.bounds

ax6.set_xlim(west, east)
ax6.set_ylim(south, north)
ax6.axis('off')
plt.savefig("images/population_blockgroups1.png",  dpi=192 * 10)
plt.show()

# %%
settry = list(set(listofids))

# %%
listofids = []
for i in range(0, len(wc_pop_bg)):
    listofids.append(str(wc_pop_bg[i]['properties']['BLOCKID10']))

# %%
listofids[0]
# Out:
# '060133400023002'

# %%
len(settry)
# Out:
# 987

# %%
max(listofpops)
# Out:
# 1265
