# %%
import shapely
import math
shapely.__file__
import fiona # need to install from src in order for buffering to work. see: https://github.com/geoplex/elasticsearch-spatial/issues/1
import sys
sys.path.append('../../alg')
import distance_buffer as db
import numpy as np

from matplotlib import pyplot

# %%
reload(db)
# Out:
# <module 'distance_buffer' from '../../alg/distance_buffer.py'>

# %%
shp = fiona.open("../../data/YukonAlaska/YukonRegionCRS.shp")

# %%
print shp.schema
l = iter(shp)
# Out:
# {'geometry': 'Polygon', 'properties': OrderedDict([(u'SASAP_Regi', 'str:100'), (u'Shape_Leng', 'float:19.11'), (u'Shape_Area', 'float:19.11')])}

# %%
first = next(l)

# %%
shp_geom = shapely.geometry.shape(first['geometry'])

# %%
# This is a sufficiently irregular shape so we will go with this one
region = shp_geom
print len(region.exterior.coords)
print len(region.interiors)
print region.area
print type(region)
regionring = region.exterior
# Out:
# 183
# 0
# 4918771.66688
# <class 'shapely.geometry.polygon.Polygon'>

# %%
shp.crs
# Out:
# {u'a': 6378137,
#  u'b': 6378137,
#  u'k': 1,
#  u'lon_0': 0,
#  u'no_defs': True,
#  u'proj': u'merc',
#  u'units': u'm',
#  u'x_0': 0,
#  u'y_0': 0}

# %%
regionring

# %%
newpoly = shapely.geometry.Polygon(list(region.exterior.coords))
print len(region.exterior.coords)
# Out:
# 183

# %%
buffer1 = newpoly.buffer(-150.0)
buffer2 = buffer1.buffer(-150.0)
buffer3 = buffer2.buffer(-150.0)
buffer4 = buffer3.buffer(-150.0)
buffers = [ newpoly, buffer1, buffer2, buffer3]

# %%
#buff1rev = buffer1.buffer(150.0)

# %%
candpts, inflpts, places = db.find_cand_points_buffers([newpoly], 100.0)
# Out:
# poly
# LINE EQ:
# y = 2.81879977217*x + 3105937.19774
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 8.81433945352 -8.81433945352
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = -0.0046975346865*x + 1324331.96937
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 3.78597207804 -3.51126220898
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 0.911510001223*x + 1902408.68142
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 2.38802077805 -2.93903119435
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 1.03660831303*x + 1981333.0166
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 1.23871189089 -3.39928141739
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = -1.34477606058*x + 479040.220796
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 1.68144491507 -2.96858860016
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 1.44206682627*x + 2237061.02038
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 5.85472803347 -0.235792952386
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 0.939797469219*x + 1920201.81199
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 5.29158367124 -1.03619934944
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 1.10269457147*x + 2022972.02419
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 5.47894427786 -2.83803656515
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = -0.680756788574*x + 897766.337876
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 1.83395202583 -5.46955450474
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = -1.35693707757*x + 471180.762764
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 1.10042208101 -7.82150054525
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = -3.87063807906*x + -1114595.60168
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 0.0981088816021 -5.96340555854
# INDEXERROR: ANGLE NOT CALCULATED
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 4.15604788246 -4.15604788246
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 1.09996229054*x + 2021066.17989
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 2.56466617562 -3.36275928681
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 0.957630760828*x + 1931272.0406
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 1.33776599591 -3.61701394945
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 0.344175048675*x + 1544224.87242
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 0.40016421278 -3.70400319738
# THIS IS A PLACE
# 145.721244555
# [ -630955.6655421   1327065.67552177] [ -630852.08341026  1327204.49461844] -630995.22314, 1327052.06078
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 4.14019857753 -4.14019857753
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 1.59593238737*x + 2334077.77367
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
#
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 0.210006730662 -2.52985769915
# THIS IS A PLACE
# 169.787904508
# [ -630913.40127501  1327752.75729514] [ -631002.44488763  1327604.19338693] -630848.718533, 1327826.77668
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 1.76201975247 -1.76201975247
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 0.851904093315*x + 1865249.38226
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 2.86814598212 -10.2691654237
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 0.85192377291*x + 1865261.79672
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 0.824803018096 -4.9754459732
# THIS IS A PLACE
# 175.231738194
# [ -630791.34803272  1327875.65158242] [ -630913.40127501  1327752.75729514] -630783.41073, 1327882.41356
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 16.610996911 -16.610996911
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 0.419547251908*x + 1592525.86008
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 1.61328504819 -1.80966302242
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = -0.00670675825874*x + 1323691.67385
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 0.861879185121 -3.50244842265
# THIS IS A PLACE
# 164.397244444
# [ -630624.2169381   1327921.11802481] [ -630791.34803272  1327875.65158242] -630613.658093, 1327921.04721
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 16.4034217553 -16.4034217553
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = -0.74989464587*x + 855027.241393
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 3.05628386205 -3.37156471627
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 113.698364068*x + 73022731.0399
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 1.97504035412 -2.92496707776
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 1.88672713496*x + 2517537.2778
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 1.43294968507 -3.62104653145
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 1.4801954555*x + 2261179.14023
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 0.324268620675 -2.97685907054
# THIS IS A PLACE
# 142.330330382
# [ -630613.25911202  1327748.25991522] [ -630624.2169381   1327921.11802481] -630644.679911, 1327701.75099
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 3.08589720591 -3.08589720591
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 1.45257248062*x + 2243758.85808
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 1.11826285041 -2.19042106796
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 1.11331047304*x + 2029784.93645
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 0.223116909133 -5.92238453751
# THIS IS A PLACE
# 172.981973244
# [ -630712.38955199  1327606.22767909] [ -630613.25911202  1327748.25991522] -630741.433203, 1327573.89308
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 3.98508646018 -3.98508646018
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 1.11328789526*x + 2029770.6957
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 3.67472404225 -6.13677941893
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 1.14142260933*x + 2047517.08937
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 0.981303080237 -2.61815986934
# THIS IS A PLACE
# 179.677319601
# [ -630827.25891221  1327476.59346337] [ -630712.38955199  1327606.22767909] -630828.444636, 1327475.24005
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 96.2597072352 -96.2597072352
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 1.18713784169*x + 2076355.55829
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 2.13725211151 -2.18211568324
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 0.759728980688*x + 1806711.80774
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 1.49965128565 -4.10067123403
# no intercept (there would be one if the line segment cont'd)
# LINE EQ:
# y = 1.09523864217*x + 2018394.61696
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 0.363691573179 -3.75239272346
# THIS IS A PLACE
# INDEXERROR: ANGLE NOT CALCULATED
# ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE ENTERING PT SEG CIRCLE
# 3.23766850295 -3.23766850295
# no intercept (there would be one if the line segment cont'd)

# %%
flat = []
flatp = []
for pts in places:
    for p in pts:
        for x in p:
            flatp.append(x)
            
print len(inflpts[1][0])
for pts in inflpts:
    for p in pts:
        for x in p:
            #if x[0] == -630758.0382403552 and x[1]== 1323597.9202250196:
            #    print "DUP"
            flat.append(x)
            
print flatp
print len(flat[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-863-fa061edfac41> in <module>()
#       6             flatp.append(x)
#       7
# ----> 8 print len(inflpts[1][0])
#       9 for pts in inflpts:
#      10     for p in pts:
#
# IndexError: list index out of range

# %%
temp = zip(*flatp)
print len(flatp)
temp2 = zip(*flat)
# Out:
# 85

# %%
testpts = [[-630955.6655421, 1327065.67552177], [-630852.08341026, 1327204.49461844]]

# %%
ax, fig = db.plot_fig(newpoly)
#xreg,yreg = region.exterior.xy
#xbuf1, ybuf1 = buffer1.exterior.xy
#db.plot_coords_list(ax, inflpts[0][0],dotsize=5.5,color="pink", alpha="1.0" , zorder=7)
#ax.scatter(temp[0], temp[1], 5.5, color="pink", zorder=7, alpha=1.0)
#ax.scatter(temp2[0], temp2[1], 5.5, color="red", zorder=7, alpha=1.0)
#[ -630955.6655421   1327065.67552177] [ -630852.08341026  1327204.49461844] -630995.22314, 1327052.06078
ax.scatter([-630955.6655421], [1327065.67552177],5.5,color="green", alpha=1.0, zorder=7)
ax.scatter([-630852.08341026 ], [1327204.49461844],5.5,color="blue", alpha=1.0, zorder=7)
ax.scatter([-630995.22314 ], [1327052.06078],5.5,color="brown", alpha=1.0, zorder=7)
ax.scatter([-630955.6655421], [1327065.67552177],5.5,color="green", alpha=1.0, zorder=7)

db.plot_coords_list(ax, inflpts[1][0],dotsize=5.5,color="pink", alpha="1.0", zorder=7)

db.plot_dist_buffers(ax, buffers, alpha=0.5)
# Out:
# num of buffers 3

# %%
for i in range(0,len(candpts)):
    #print list(candpts[i])
    for j in range(0, len(candpts[i])):
        db.plot_coords_list(ax, candpts[i][j], color="#000000", zorder=3 )
        db.plot_radii(ax, candpts[i][j], 100.0, color='red', zorder=4, alpha=0.3)
        #print "\t"+str(len(candpts[i][j]))
        #for k in range(0, len(candpts[i][j])):
            
            
            #print "\t\t"+str(len(candpts[i][j][k]))
            #print list(candpts[i][j][k])

# %%
ab=db.ang_bw_vectors(np.array([-630955.6655421,1327065.67552177]), np.array([-630852.08341026,1327204.49461844]), np.array([-630955.6655421,1327065.67552177]), np.array([-630995.22314 ,1327052.06078]))
np.rad2deg(ab)
# Out:
# 145.72124920177549

# %%
#ax.plot([c1[0], c2[0]], [c1[1], c2[1]], color="green", alpha=0.5)
ax.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]], color="blue", alpha=0.5)
pyplot.show()

# %%
shapely.
# Out:
#   File "<ipython-input-861-a06419a5fba1>", line 1
#     shapely.
#             ^
# SyntaxError: invalid syntax

# %%
print len(buffer1.exterior.coords)
print len(newpoly.exterior.coords)

# %%
#c2 = np.array([ -631079.88319404,  1324653.40708579])
c1 = np.array(candpts[0][0][2])
c2 = np.array(candpts[0][0][3])
pt1 = np.array(newpoly.exterior.coords[165])
pt2 = np.array(newpoly.exterior.coords[179])

# %%
db.eucdist(pt1[0],pt1[1],pt2[0],pt2[1])

# %%
(100*math.sqrt(3))/2

# %%
print pt1, pt2, c1, c2

# %%
print pt2

# %%
vec1 = np.array(c2-c1)
vec1n = vec1 / np.linalg.norm(vec1)
vec2 = np.array(pt2-pt1)
vec2n = vec2 / np.linalg.norm(vec2)

# %%
print vec1, vec2
print vec1n, vec2n

# %%
dp = np.dot(vec1n, vec2n)

# %%
ang = np.rad2deg(math.acos(dp))
print ang

# %%
angt = db.ang_bw_vectors(c1, c2, c1, pt2)
print np.rad2deg(angt)
